# %%
import pandas as pd

# %%
df = pd.read_csv('pruned_adult500.csv')

# %%
list(df)
# Out:
# ['_tid_',
#  'age',
#  'workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'hours-per-week',
#  'native-country',
#  'income']

# %%
df.head()
# Out:
#    _tid_  age workclass     education         marital-status  \
# 0      0   45   private       hs-grad  married-spouse-absent
# 1      1   61   private  some-college     married-civ-spouse
# 2      2   37   private       hs-grad          never-married
# 3      3   41   private       5th-6th     married-civ-spouse
# 4      4   32   private     bachelors     married-civ-spouse
#
#           occupation   relationship   race   sex hours-per-week  \
# 0       craft-repair  not-in-family  white  male             72
# 1    exec-managerial        husband  white  male             45
# 2  handlers-cleaners  not-in-family  white  male             40
# 3       adm-clerical        husband  white  male             40
# 4     prof-specialty        husband  white  male             60
#
#   native-country income
# 0         mexico  <=50k
# 1  united-states   >50k
# 2  united-states  <=50k
# 3         mexico  <=50k
# 4  united-states   >50k

# %%
# df[df['_tid_']==10]['education']='wahaha'
df.loc[df['_tid_'] ==5 , ['education']] = 'wa?'

# %%
df.head(10)
# Out:
#    _tid_  age  workclass     education         marital-status  \
# 0      0   45    private       hs-grad  married-spouse-absent
# 1      1   61    private  some-college     married-civ-spouse
# 2      2   37    private       hs-grad          never-married
# 3      3   41    private       5th-6th     married-civ-spouse
# 4      4   32    private     bachelors     married-civ-spouse
# 5      5   32  state-gov           wa?          never-married
# 6      6   18    private          11th          never-married
# 7      7   29    private     assoc-voc     married-civ-spouse
# 8      8   33    private       hs-grad          never-married
# 9      9   26    private     bachelors          never-married
#
#           occupation    relationship   race     sex hours-per-week  \
# 0       craft-repair   not-in-family  white    male             72
# 1    exec-managerial         husband  white    male             45
# 2  handlers-cleaners   not-in-family  white    male             40
# ...
