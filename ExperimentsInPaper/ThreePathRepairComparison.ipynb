# %%
import glob
import pickle

# %%
# 2
f2s = []
for f2 in glob.glob('pickle_files/path_repair_tweets-tweets_sample_params_2*.pkl'):
    print(f2)
    f2s.append(f2)
print('\n')

# 4 
f4s = []
for f4 in glob.glob('pickle_files/path_repair_tweets-tweets_sample_params_4*.pkl')[-3:]:
    f4s.append(f4)
print('\n')

# 6
f6s = []
for f6 in glob.glob('pickle_files/path_repair_tweets-tweets_sample_params_6*.pkl'):
    print(f6)
    f6s.append(f6)
print('\n')

# 8
f8s = []
for f8 in glob.glob('pickle_files/path_repair_tweets-tweets_sample_params_8*.pkl'):
    print(f8)
    f8s.append(f8)
print('\n')

# 10
f10s = []
for f10 in glob.glob('pickle_files/path_repair_tweets-tweets_sample_params_10*.pkl')[-2:]:
    print(f10)
    f10s.append(f10)
f10s.append('')
print('\n')
# Out:
# pickle_files/path_repair_tweets-tweets_sample_params_2-0.7-0.8-0.8-1-20241017_075210.pkl
# pickle_files/path_repair_tweets-tweets_sample_params_2-0.7-0.8-0.8-1-20241017_075221.pkl
# pickle_files/path_repair_tweets-tweets_sample_params_2-0.7-0.8-0.8-1-20241017_075230.pkl
#
#
#
#
# pickle_files/path_repair_tweets-tweets_sample_params_6-0.7-0.8-0.8-1-20241017_145259.pkl
# pickle_files/path_repair_tweets-tweets_sample_params_6-0.7-0.8-0.8-1-20241017_145312.pkl
# pickle_files/path_repair_tweets-tweets_sample_params_6-0.7-0.8-0.8-1-20241017_145502.pkl
#
#
# pickle_files/path_repair_tweets-tweets_sample_params_8-0.7-0.8-0.8-1-20241017_145927.pkl
# pickle_files/path_repair_tweets-tweets_sample_params_8-0.7-0.8-0.8-1-20241017_145940.pkl
# pickle_files/path_repair_tweets-tweets_sample_params_8-0.7-0.8-0.8-1-20241017_151701.pkl
#
#
# pickle_files/path_repair_tweets-tweets_sample_params_10-0.7-0.8-0.8-1-20241017_134041.pkl
# pickle_files/path_repair_tweets-tweets_sample_params_10-0.7-0.8-0.8-1-20241017_134058.pkl

# %%
strats = ['greedy', 'entropy', 'brute force']

# %%
fs_with_strats = {}

# %%
for fs in [f2s, f4s, f6s, f8s, f10s]:
    for f,s in zip(fs,strats):
        fs_with_strats[f]=s

# %%
dfs = []

# %%
import pandas as pd

# %%
for f in fs_with_strats:
    if(f):
        with open(f, 'rb') as x:
            res_f = pickle.load(x)
            df_f = pd.DataFrame([res_f['summary']])
            df_f['avg_tree_size'] = sum([m['rule'].size for m in res_f['fix_details'].values()]) / len(res_f['fix_details'])
            df_f['strat']=fs_with_strats[f]
            display(df_f)
            dfs.append(df_f)
# Out:
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092                2            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0                1.0                1.0             0.565267
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                      0.565267
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 4.580155611038208, 'snor...                     23.0
#
#    avg_tree_size   strat
# 0          6.125  greedy
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092                2            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0                1.0                1.0             0.565267
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                      0.565267
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 5.427846431732178, 'snor...                     23.0
#
#    avg_tree_size    strat
# 0          5.875  entropy
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092                2            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0                1.0                0.0             0.573893
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                      0.573893
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 4.003216505050659, 'snor...                     23.0
#
#    avg_tree_size        strat
# 0          5.375  brute force
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092                4            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0                1.0                0.0             0.468979
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                      0.468979
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 4.4744977951049805, 'sno...                     43.0
#
#    avg_tree_size   strat
# 0          8.125  greedy
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092                4            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0                0.5                1.0             0.418264
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                      0.418264
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 4.341078996658325, 'snor...                     43.0
#
#    avg_tree_size    strat
# 0          6.875  entropy
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092                4            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0                0.5                1.0             0.418264
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                      0.418264
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 4.189564228057861, 'snor...                     43.0
#
#    avg_tree_size        strat
# 0          6.875  brute force
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092                6            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0                1.0           0.666667             0.541391
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                      0.541391
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 5.571043491363525, 'snor...                     64.0
#
#    avg_tree_size   strat
# 0         11.125  greedy
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092                6            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0                1.0                1.0             0.475253
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                      0.475253
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 5.405680418014526, 'snor...                     64.0
#
#    avg_tree_size    strat
# 0           7.75  entropy
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092                6            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0           0.666667                1.0             0.690659
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                      0.690659
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 3.9920389652252197, 'sno...                     64.0
#
#    avg_tree_size        strat
# 0           7.75  brute force
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092                8            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0                1.0               0.75              0.57703
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                       0.57703
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 4.507023096084595, 'snor...                     87.0
#
#    avg_tree_size   strat
# 0          14.75  greedy
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092                8            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0                1.0                1.0             0.700505
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                      0.700505
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 4.1178576946258545, 'sno...                     87.0
#
#    avg_tree_size    strat
# 0          9.375  entropy
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092                8            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0               0.75                1.0             0.670443
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                      0.670443
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 4.3080315589904785, 'sno...                     87.0
#
#    avg_tree_size        strat
# 0          8.875  brute force
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092               10            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0                1.0                0.6             0.660247
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                      0.660247
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 4.393285751342773, 'snor...                    111.0
#
#    avg_tree_size   strat
# 0          17.75  greedy
#    before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                    0.544092               10            0.7
#
#    instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                  0.8                     0.8       tweets             1
#
#    confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0                0.4                0.6             0.547055
#
#    global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                       0.593085                      0.547055
#
#    valid_global_data_size  new_valid_global_data_size  \
# 0                   10528                       11476
#
#                                             runtimes  optimal_objective_value  \
# 0  {'snorkel_first_run': 4.433809280395508, 'snor...                    111.0
#
#    avg_tree_size    strat
# 0          11.25  entropy

# %%
df_res = pd.concat(dfs).reset_index(drop=True)

# %%
df_res
# Out:
#     before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                     0.544092                2            0.7
# 1                     0.544092                2            0.7
# 2                     0.544092                2            0.7
# 3                     0.544092                4            0.7
# 4                     0.544092                4            0.7
# 5                     0.544092                4            0.7
# 6                     0.544092                6            0.7
# 7                     0.544092                6            0.7
# 8                     0.544092                6            0.7
# 9                     0.544092                8            0.7
# 10                    0.544092                8            0.7
# 11                    0.544092                8            0.7
# 12                    0.544092               10            0.7
# 13                    0.544092               10            0.7
#
#     instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                   0.8                     0.8       tweets             1
# 1                   0.8                     0.8       tweets             1
# 2                   0.8                     0.8       tweets             1
# 3                   0.8                     0.8       tweets             1
# 4                   0.8                     0.8       tweets             1
# 5                   0.8                     0.8       tweets             1
# 6                   0.8                     0.8       tweets             1
# 7                   0.8                     0.8       tweets             1
# 8                   0.8                     0.8       tweets             1
# 9                   0.8                     0.8       tweets             1
# 10                  0.8                     0.8       tweets             1
# 11                  0.8                     0.8       tweets             1
# 12                  0.8                     0.8       tweets             1
# 13                  0.8                     0.8       tweets             1
#
#     confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0            1.000000           1.000000             0.565267
# 1            1.000000           1.000000             0.565267
# 2            1.000000           0.000000             0.573893
# 3            1.000000           0.000000             0.468979
# 4            0.500000           1.000000             0.418264
# 5            0.500000           1.000000             0.418264
# 6            1.000000           0.666667             0.541391
# 7            1.000000           1.000000             0.475253
# 8            0.666667           1.000000             0.690659
# 9            1.000000           0.750000             0.577030
# 10           1.000000           1.000000             0.700505
# 11           0.750000           1.000000             0.670443
# 12           1.000000           0.600000             0.660247
# 13           0.400000           0.600000             0.547055
#
#     global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 0                        0.593085                      0.565267
# 1                        0.593085                      0.565267
# 2                        0.593085                      0.573893
# 3                        0.593085                      0.468979
# 4                        0.593085                      0.418264
# 5                        0.593085                      0.418264
# 6                        0.593085                      0.541391
# 7                        0.593085                      0.475253
# 8                        0.593085                      0.690659
# 9                        0.593085                      0.577030
# 10                       0.593085                      0.700505
# 11                       0.593085                      0.670443
# 12                       0.593085                      0.660247
# 13                       0.593085                      0.547055
#
#     valid_global_data_size  new_valid_global_data_size  \
# 0                    10528                       11476
# 1                    10528                       11476
# 2                    10528                       11476
# 3                    10528                       11476
# 4                    10528                       11476
# 5                    10528                       11476
# 6                    10528                       11476
# 7                    10528                       11476
# 8                    10528                       11476
# 9                    10528                       11476
# 10                   10528                       11476
# 11                   10528                       11476
# 12                   10528                       11476
# 13                   10528                       11476
#
#                                              runtimes  \
# 0   {'snorkel_first_run': 4.580155611038208, 'snor...
# 1   {'snorkel_first_run': 5.427846431732178, 'snor...
# 2   {'snorkel_first_run': 4.003216505050659, 'snor...
# 3   {'snorkel_first_run': 4.4744977951049805, 'sno...
# 4   {'snorkel_first_run': 4.341078996658325, 'snor...
# 5   {'snorkel_first_run': 4.189564228057861, 'snor...
# 6   {'snorkel_first_run': 5.571043491363525, 'snor...
# 7   {'snorkel_first_run': 5.405680418014526, 'snor...
# 8   {'snorkel_first_run': 3.9920389652252197, 'sno...
# 9   {'snorkel_first_run': 4.507023096084595, 'snor...
# 10  {'snorkel_first_run': 4.1178576946258545, 'sno...
# 11  {'snorkel_first_run': 4.3080315589904785, 'sno...
# 12  {'snorkel_first_run': 4.393285751342773, 'snor...
# 13  {'snorkel_first_run': 4.433809280395508, 'snor...
#
#     optimal_objective_value  avg_tree_size        strat
# 0                      23.0          6.125       greedy
# 1                      23.0          5.875      entropy
# 2                      23.0          5.375  brute force
# 3                      43.0          8.125       greedy
# 4                      43.0          6.875      entropy
# 5                      43.0          6.875  brute force
# 6                      64.0         11.125       greedy
# 7                      64.0          7.750      entropy
# 8                      64.0          7.750  brute force
# 9                      87.0         14.750       greedy
# 10                     87.0          9.375      entropy
# 11                     87.0          8.875  brute force
# 12                    111.0         17.750       greedy
# 13                    111.0         11.250      entropy

# %%
df_expanded = pd.json_normalize(df_res['runtimes'])

# Join the expanded columns back to the original DataFrame (excluding the original dictionary column)
df_res = df_res.drop(columns=['runtimes']).join(df_expanded)

# %%
df_res
# Out:
#     before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                     0.544092                2            0.7
# 1                     0.544092                2            0.7
# 2                     0.544092                2            0.7
# 3                     0.544092                4            0.7
# 4                     0.544092                4            0.7
# 5                     0.544092                4            0.7
# 6                     0.544092                6            0.7
# 7                     0.544092                6            0.7
# 8                     0.544092                6            0.7
# 9                     0.544092                8            0.7
# 10                    0.544092                8            0.7
# 11                    0.544092                8            0.7
# 12                    0.544092               10            0.7
# 13                    0.544092               10            0.7
#
#     instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 0                   0.8                     0.8       tweets             1
# 1                   0.8                     0.8       tweets             1
# 2                   0.8                     0.8       tweets             1
# 3                   0.8                     0.8       tweets             1
# 4                   0.8                     0.8       tweets             1
# 5                   0.8                     0.8       tweets             1
# 6                   0.8                     0.8       tweets             1
# 7                   0.8                     0.8       tweets             1
# 8                   0.8                     0.8       tweets             1
# 9                   0.8                     0.8       tweets             1
# 10                  0.8                     0.8       tweets             1
# 11                  0.8                     0.8       tweets             1
# 12                  0.8                     0.8       tweets             1
# 13                  0.8                     0.8       tweets             1
#
#     confirm_prev_rate  complain_fix_rate  new_global_accuracy  ...  \
# 0            1.000000           1.000000             0.565267  ...
# 1            1.000000           1.000000             0.565267  ...
# 2            1.000000           0.000000             0.573893  ...
# 3            1.000000           0.000000             0.468979  ...
# 4            0.500000           1.000000             0.418264  ...
# 5            0.500000           1.000000             0.418264  ...
# 6            1.000000           0.666667             0.541391  ...
# 7            1.000000           1.000000             0.475253  ...
# 8            0.666667           1.000000             0.690659  ...
# 9            1.000000           0.750000             0.577030  ...
# 10           1.000000           1.000000             0.700505  ...
# 11           0.750000           1.000000             0.670443  ...
# 12           1.000000           0.600000             0.660247  ...
# 13           0.400000           0.600000             0.547055  ...
#
#     new_global_accuracy_on_valid  valid_global_data_size  \
# 0                       0.565267                   10528
# 1                       0.565267                   10528
# 2                       0.573893                   10528
# 3                       0.468979                   10528
# 4                       0.418264                   10528
# 5                       0.418264                   10528
# 6                       0.541391                   10528
# 7                       0.475253                   10528
# 8                       0.690659                   10528
# 9                       0.577030                   10528
# 10                      0.700505                   10528
# 11                      0.670443                   10528
# 12                      0.660247                   10528
# 13                      0.547055                   10528
#
#     new_valid_global_data_size  optimal_objective_value  avg_tree_size  \
# 0                        11476                     23.0          6.125
# 1                        11476                     23.0          5.875
# 2                        11476                     23.0          5.375
# 3                        11476                     43.0          8.125
# 4                        11476                     43.0          6.875
# 5                        11476                     43.0          6.875
# 6                        11476                     64.0         11.125
# 7                        11476                     64.0          7.750
# 8                        11476                     64.0          7.750
# 9                        11476                     87.0         14.750
# 10                       11476                     87.0          9.375
# 11                       11476                     87.0          8.875
# 12                       11476                    111.0         17.750
# 13                       11476                    111.0         11.250
#
#           strat snorkel_first_run  snorkel_run_after_fix  solver_runtime  \
# 0        greedy          4.580156               5.232861        0.090678
# 1       entropy          5.427846               5.402336        0.091569
# 2   brute force          4.003217               5.066155        0.092417
# 3        greedy          4.474498               6.739093        0.283196
# 4       entropy          4.341079               6.490574        0.279999
# 5   brute force          4.189564               6.545919        0.281799
# 6        greedy          5.571043              10.308227        0.353495
# 7       entropy          5.405680               6.862836        0.347098
# 8   brute force          3.992039              12.572159        0.340112
# 9        greedy          4.507023              10.444350        0.584607
# 10      entropy          4.117858               7.804489        0.594642
# 11  brute force          4.308032               7.645177        0.589778
# 12       greedy          4.393286              12.052054        2.788347
# 13      entropy          4.433809               8.913968        2.784727
#
#     repair_time
# 0      0.008562
# 1      0.010684
# 2      0.036088
# 3      0.015754
# 4      0.037400
# 5      0.972484
# 6      0.023987
# 7      0.072906
# 8     92.838434
# 9      0.034847
# 10     0.135590
# 11  1029.072790
# 12     0.043235
# 13     0.219667
#
# [14 rows x 21 columns]

# %%
# df_res.to_csv('three_strat_comparison.csv', index=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = df_res

df_filtered = df[['user_input_size', 'strat', 'repair_time', 'avg_tree_size']].copy()

colorblind_colors = ['#0072B2', '#D55E00', '#009E73', '#CC79A7', '#F0E442', '#56B4E9']

fig, ax1 = plt.subplots(figsize=(6, 4))

n_strats = len(df_filtered['strat'].unique())
bar_width = 0.4  
plt.rcParams.update({'font.size': 14})

for i, strat in enumerate(df_filtered['strat'].unique()):
    data = df_filtered[df_filtered['strat'] == strat]
    positions = data['user_input_size'] + (i - n_strats / 2) * bar_width
    ax1.bar(positions, data['repair_time'], width=bar_width, label=f'{strat}', color=colorblind_colors[i], alpha=0.8)

ax1.set_yscale('log')

ax1.set_xlabel('# data points', fontsize=16)
ax1.set_ylabel('runtime', fontsize=16)
# ax1.set_title('Refinement time by Path Repair Algo', fontsize=18)
ax1.legend(fontsize=14)

fig.savefig('three_strat_repair_time_plot.png', dpi=300, bbox_inches='tight')

fig, ax2 = plt.subplots(figsize=(6, 4))

for i, strat in enumerate(df_filtered['strat'].unique()):
    data = df_filtered[df_filtered['strat'] == strat]
    ax2.plot(data['user_input_size'], data['avg_tree_size'], label=f'{strat}', marker='o', linestyle='-', color=colorblind_colors[i], linewidth=2.5)

ax2.set_xlabel('# data points', fontsize=16)
ax2.set_ylabel('avg rule size', fontsize=16)
# ax2.set_title('Avg Rule Size by Path Repair Algo', fontsize=18)
ax2.legend(fontsize=14)

fig.savefig('three_strat_avg_rule_size_plot.png', dpi=300, bbox_inches='tight')



plt.tight_layout()
plt.show()
