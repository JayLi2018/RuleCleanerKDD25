# %%
import pickle
import pandas as pd
import glob
import sys
sys.path.append("/Users/chenjieli/Desktop/RuleCleaner/")

# %%
def process_results(directory):
    dicts = []
    for fname in glob.glob(directory+'*.pkl'):
        with open(fname,'rb') as f:
            d = pickle.load(f)['summary']
            dicts.append(d)
    return dicts

# %%
if __name__ == '__main__':
    directory = '../rulecleaner_src/test_folder_multi_class_chemprot/'
    dicts = process_results(directory)

# %%
df = pd.DataFrame(dicts)

# %%
df['runtimes'].to_list()
# Out:
# [{'snorkel_first_run': 2.5822179317474365,
#   'snorkel_run_after_fix': 10.052963256835938,
#   'solver_runtime': 3.9830009937286377,
#   'repair_time': 4.489415884017944},
#  {'snorkel_first_run': 2.5023269653320312,
#   'snorkel_run_after_fix': 16.29085612297058,
#   'solver_runtime': 8.850212097167969,
#   'repair_time': 26.968798875808716},
#  {'snorkel_first_run': 2.3969500064849854,
#   'snorkel_run_after_fix': 10.99249792098999,
#   'solver_runtime': 4.022154092788696,
#   'repair_time': 5.9029319286346436},
#  {'snorkel_first_run': 2.484308958053589,
#   'snorkel_run_after_fix': 19.261505126953125,
#   'solver_runtime': 19.35962414741516,
#   'repair_time': 110.29069590568542},
#  {'snorkel_first_run': 2.2640280723571777,
#   'snorkel_run_after_fix': 8.724956750869751,
#   'solver_runtime': 1.8816969394683838,
#   'repair_time': 1.2555530071258545},
#  {'snorkel_first_run': 2.4057087898254395,
#   'snorkel_run_after_fix': 16.849714279174805,
#   'solver_runtime': 15.092628955841064,
#   'repair_time': 56.936723947525024},
#  {'snorkel_first_run': 2.377825975418091,
#   'snorkel_run_after_fix': 15.673804998397827,
#   'solver_runtime': 14.531958103179932,
#   'repair_time': 50.06205677986145},
#  {'snorkel_first_run': 2.3867249488830566,
#   'snorkel_run_after_fix': 17.237390756607056,
#   'solver_runtime': 18.66488027572632,
#   'repair_time': 97.39622783660889},
#  {'snorkel_first_run': 2.309006690979004,
#   'snorkel_run_after_fix': 11.076812982559204,
#   'solver_runtime': 3.9880590438842773,
#   'repair_time': 5.745384931564331},
#  {'snorkel_first_run': 2.2665300369262695,
#   'snorkel_run_after_fix': 16.301057815551758,
#   'solver_runtime': 13.706958055496216,
#   'repair_time': 67.83420896530151},
#  {'snorkel_first_run': 2.5846798419952393,
#   'snorkel_run_after_fix': 9.522508144378662,
#   'solver_runtime': 1.9332408905029297,
#   'repair_time': 1.2534921169281006},
#  {'snorkel_first_run': 2.611570119857788,
#   'snorkel_run_after_fix': 14.284750938415527,
#   'solver_runtime': 8.681686639785767,
#   'repair_time': 22.374479055404663},
#  {'snorkel_first_run': 2.4085750579833984,
#   'snorkel_run_after_fix': 18.085843086242676,
#   'solver_runtime': 19.456063985824585,
#   'repair_time': 93.75239992141724},
#  {'snorkel_first_run': 2.3673810958862305,
#   'snorkel_run_after_fix': 7.6814069747924805,
#   'solver_runtime': 2.093888998031616,
#   'repair_time': 1.0086009502410889},
#  {'snorkel_first_run': 2.339625835418701,
#   'snorkel_run_after_fix': 11.788864612579346,
#   'solver_runtime': 8.994516372680664,
#   'repair_time': 19.721499919891357},
#  {'snorkel_first_run': 2.485621929168701,
#   'snorkel_run_after_fix': 16.362653017044067,
#   'solver_runtime': 19.465473175048828,
#   'repair_time': 80.76522922515869},
#  {'snorkel_first_run': 2.352189302444458,
#   'snorkel_run_after_fix': 16.77889919281006,
#   'solver_runtime': 13.878393173217773,
#   'repair_time': 62.90432000160217},
#  {'snorkel_first_run': 2.308366060256958,
#   'snorkel_run_after_fix': 17.60068416595459,
#   'solver_runtime': 14.091454029083252,
#   'repair_time': 72.1691267490387},
#  {'snorkel_first_run': 2.5194220542907715,
#   'snorkel_run_after_fix': 18.84032416343689,
#   'solver_runtime': 20.379534244537354,
#   'repair_time': 93.03446698188782},
#  {'snorkel_first_run': 2.5703930854797363,
#   'snorkel_run_after_fix': 11.1878080368042,
#   'solver_runtime': 3.9504880905151367,
#   'repair_time': 5.148384094238281},
#  {'snorkel_first_run': 2.5558929443359375,
#   'snorkel_run_after_fix': 19.32946276664734,
#   'solver_runtime': 19.506664037704468,
#   'repair_time': 96.34650802612305},
#  {'snorkel_first_run': 2.3821351528167725,
#   'snorkel_run_after_fix': 19.373379945755005,
#   'solver_runtime': 13.955751180648804,
#   'repair_time': 69.7493999004364},
#  {'snorkel_first_run': 2.4384918212890625,
#   'snorkel_run_after_fix': 14.240240812301636,
#   'solver_runtime': 8.948460102081299,
#   'repair_time': 29.254395961761475},
#  {'snorkel_first_run': 2.413106918334961,
#   'snorkel_run_after_fix': 11.024573802947998,
#   'solver_runtime': 3.760780096054077,
#   'repair_time': 6.436676025390625},
#  {'snorkel_first_run': 2.767624855041504,
#   'snorkel_run_after_fix': 8.626485109329224,
#   'solver_runtime': 1.7769689559936523,
#   'repair_time': 1.430145025253296},
#  {'snorkel_first_run': 2.3508200645446777,
#   'snorkel_run_after_fix': 16.2274112701416,
#   'solver_runtime': 13.927073955535889,
#   'repair_time': 59.40709376335144},
#  {'snorkel_first_run': 2.3043768405914307,
#   'snorkel_run_after_fix': 19.31653881072998,
#   'solver_runtime': 18.81789207458496,
#   'repair_time': 97.99364590644836},
#  {'snorkel_first_run': 2.312045097351074,
#   'snorkel_run_after_fix': 18.438572883605957,
#   'solver_runtime': 18.779602766036987,
#   'repair_time': 100.47350001335144},
#  {'snorkel_first_run': 2.4730801582336426,
#   'snorkel_run_after_fix': 9.960700035095215,
#   'solver_runtime': 4.115182876586914,
#   'repair_time': 5.28630805015564},
#  {'snorkel_first_run': 2.569164991378784,
#   'snorkel_run_after_fix': 11.318542003631592,
#   'solver_runtime': 4.235714912414551,
#   'repair_time': 4.897859811782837},
#  {'snorkel_first_run': 2.3555519580841064,
#   'snorkel_run_after_fix': 13.91987919807434,
#   'solver_runtime': 8.581869840621948,
#   'repair_time': 25.32959485054016},
#  {'snorkel_first_run': 2.3415918350219727,
#   'snorkel_run_after_fix': 15.166374921798706,
#   'solver_runtime': 14.37836503982544,
#   'repair_time': 53.0617299079895},
#  {'snorkel_first_run': 2.351478099822998,
#   'snorkel_run_after_fix': 14.819716930389404,
#   'solver_runtime': 8.398206949234009,
#   'repair_time': 29.864726781845093},
#  {'snorkel_first_run': 2.3410019874572754,
#   'snorkel_run_after_fix': 10.20944881439209,
#   'solver_runtime': 1.7669520378112793,
#   'repair_time': 1.458662748336792},
#  {'snorkel_first_run': 2.2917611598968506,
#   'snorkel_run_after_fix': 15.407812118530273,
#   'solver_runtime': 8.31939697265625,
#   'repair_time': 27.747308015823364},
#  {'snorkel_first_run': 2.4073069095611572,
#   'snorkel_run_after_fix': 15.428241968154907,
#   'solver_runtime': 9.118208169937134,
#   'repair_time': 27.83523917198181},
#  {'snorkel_first_run': 2.4923431873321533,
#   'snorkel_run_after_fix': 8.2186758518219,
#   'solver_runtime': 1.8626389503479004,
#   'repair_time': 1.0719411373138428},
#  {'snorkel_first_run': 2.384390115737915,
#   'snorkel_run_after_fix': 8.277520895004272,
#   'solver_runtime': 1.6853208541870117,
#   'repair_time': 1.54109525680542},
#  {'snorkel_first_run': 2.3352878093719482,
#   'snorkel_run_after_fix': 10.131941080093384,
#   'solver_runtime': 2.3927900791168213,
#   'repair_time': 1.659919023513794},
#  {'snorkel_first_run': 2.5486860275268555,
#   'snorkel_run_after_fix': 11.7066171169281,
#   'solver_runtime': 3.9759769439697266,
#   'repair_time': 6.4554338455200195}]

# %%
# Expand the dictionary column into separate columns
df_expanded = df["runtimes"].apply(pd.Series)

# If you want to merge it back with the original DataFrame (optional)
df_final = pd.concat([df, df_expanded], axis=1)

# %%
list(df_final)
# Out:
# ['before_fix_global_accuracy',
#  'user_input_size',
#  'lf_acc_thresh',
#  'instance_acc_thresh',
#  'min_non_abstain_thresh',
#  'dataset_name',
#  'random_state',
#  'confirm_prev_rate',
#  'complain_fix_rate',
#  'new_global_accuracy',
#  'global_accuracy_on_valid_data',
#  'new_global_accuracy_on_valid',
#  'valid_global_data_size',
#  'new_valid_global_data_size',
#  'runtimes',
#  'optimal_objective_value',
#  'snorkel_first_run',
#  'snorkel_run_after_fix',
#  'solver_runtime',
#  'repair_time']

# %%
df_final.sort_values(by='dataset_name')[['dataset_name','before_fix_global_accuracy','user_input_size','random_state','new_global_accuracy', 'snorkel_first_run',
 'snorkel_run_after_fix',
 'solver_runtime',
 'repair_time']]
# Out:
#    dataset_name  before_fix_global_accuracy  user_input_size  random_state  \
# 0      chemprot                    0.452566               40             7
# 22     chemprot                    0.452566               80             8
# 23     chemprot                    0.452566               40             8
# 24     chemprot                    0.452566               20             1
# 25     chemprot                    0.452566              120             2
# 26     chemprot                    0.452566              150             1
# 27     chemprot                    0.452566              150             5
# 28     chemprot                    0.452566               40             6
# 21     chemprot                    0.452566              120             5
# 29     chemprot                    0.452566               40             4
# 31     chemprot                    0.452566              120             7
# 32     chemprot                    0.452566               80             1
# 33     chemprot                    0.452566               20             4
# 34     chemprot                    0.452566               80             6
# 35     chemprot                    0.452566               80             3
# 36     chemprot                    0.452566               20             8
# 37     chemprot                    0.452566               20             2
# 30     chemprot                    0.452566               80             2
# 20     chemprot                    0.452566              150             3
# 19     chemprot                    0.452566               40             5
# 18     chemprot                    0.452566              150             4
# 1      chemprot                    0.452566               80             5
# 2      chemprot                    0.452566               40             2
# 3      chemprot                    0.452566              150             6
# 4      chemprot                    0.452566               20             3
# 5      chemprot                    0.452566              120             1
# 6      chemprot                    0.452566              120             4
# 7      chemprot                    0.452566              150             8
# 8      chemprot                    0.452566               40             3
# 9      chemprot                    0.452566              120             8
# 10     chemprot                    0.452566               20             7
# 11     chemprot                    0.452566               80             4
# 12     chemprot                    0.452566              150             2
# 13     chemprot                    0.452566               20             6
# 14     chemprot                    0.452566               80             7
# 15     chemprot                    0.452566              150             7
# 16     chemprot                    0.452566              120             6
# 17     chemprot                    0.452566              120             3
# 38     chemprot                    0.452566               20             5
# 39     chemprot                    0.452566               40             1
#
#     new_global_accuracy  snorkel_first_run  snorkel_run_after_fix  \
# 0              0.418227           2.582218              10.052963
# 22             0.343266           2.438492              14.240241
# 23             0.351415           2.413107              11.024574
# 24             0.140280           2.767625               8.626485
# 25             0.454308           2.350820              16.227411
# 26             0.401804           2.304377              19.316539
# 27             0.461586           2.312045              18.438573
# 28             0.403173           2.473080               9.960700
# 21             0.439191           2.382135              19.373380
# 29             0.366843           2.569165              11.318542
# 31             0.430233           2.341592              15.166375
# 32             0.370824           2.351478              14.819717
# 33             0.307745           2.341002              10.209449
# 34             0.414308           2.291761              15.407812
# 35             0.371882           2.407307              15.428242
# 36             0.263328           2.492343               8.218676
# 37             0.263888           2.384390               8.277521
# 30             0.435272           2.355552              13.919879
# 20             0.420715           2.555893              19.329463
# 19             0.352286           2.570393              11.187808
# 18             0.429860           2.519422              18.840324
# 1              0.370078           2.502327              16.290856
# 2              0.443359           2.396950              10.992498
# 3              0.435459           2.484309              19.261505
# 4              0.325163           2.264028               8.724957
# 5              0.414059           2.405709              16.849714
# 6              0.439378           2.377826              15.673805
# 7              0.403857           2.386725              17.237391
# 8              0.364479           2.309007              11.076813
# 9              0.421711           2.266530              16.301058
# 10             0.354712           2.584680               9.522508
# 11             0.433157           2.611570              14.284751
# 12             0.426563           2.408575              18.085843
# 13             0.369953           2.367381               7.681407
# 14             0.396765           2.339626              11.788865
# 15             0.439316           2.485622              16.362653
# 16             0.409331           2.352189              16.778899
# 17             0.391726           2.308366              17.600684
# 38             0.311602           2.335288              10.131941
# 39             0.330451           2.548686              11.706617
#
#     solver_runtime  repair_time
# 0         3.983001     4.489416
# 22        8.948460    29.254396
# 23        3.760780     6.436676
# 24        1.776969     1.430145
# 25       13.927074    59.407094
# 26       18.817892    97.993646
# 27       18.779603   100.473500
# 28        4.115183     5.286308
# 21       13.955751    69.749400
# 29        4.235715     4.897860
# 31       14.378365    53.061730
# 32        8.398207    29.864727
# 33        1.766952     1.458663
# 34        8.319397    27.747308
# 35        9.118208    27.835239
# 36        1.862639     1.071941
# 37        1.685321     1.541095
# 30        8.581870    25.329595
# 20       19.506664    96.346508
# 19        3.950488     5.148384
# 18       20.379534    93.034467
# 1         8.850212    26.968799
# 2         4.022154     5.902932
# 3        19.359624   110.290696
# 4         1.881697     1.255553
# 5        15.092629    56.936724
# 6        14.531958    50.062057
# 7        18.664880    97.396228
# 8         3.988059     5.745385
# 9        13.706958    67.834209
# 10        1.933241     1.253492
# 11        8.681687    22.374479
# 12       19.456064    93.752400
# 13        2.093889     1.008601
# 14        8.994516    19.721500
# 15       19.465473    80.765229
# 16       13.878393    62.904320
# 17       14.091454    72.169127
# 38        2.392790     1.659919
# 39        3.975977     6.455434

# %%
df_final.head()['runtimes']
# Out:
# 0    {'snorkel_first_run': 2.5822179317474365, 'sno...
# 1    {'snorkel_first_run': 2.5023269653320312, 'sno...
# 2    {'snorkel_first_run': 2.3969500064849854, 'sno...
# 3    {'snorkel_first_run': 2.484308958053589, 'snor...
# 4    {'snorkel_first_run': 2.2640280723571777, 'sno...
# Name: runtimes, dtype: object

# %%
df[df['user_input_size']==40].sort_values(by='new_global_accuracy')
# Out:
#     before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 39                    0.452566               40            0.7
# 23                    0.452566               40            0.7
# 19                    0.452566               40            0.7
# 8                     0.452566               40            0.7
# 29                    0.452566               40            0.7
# 28                    0.452566               40            0.7
# 0                     0.452566               40            0.7
# 2                     0.452566               40            0.7
#
#     instance_acc_thresh  min_non_abstain_thresh dataset_name  random_state  \
# 39                  0.8                     0.8     chemprot             1
# 23                  0.8                     0.8     chemprot             8
# 19                  0.8                     0.8     chemprot             5
# 8                   0.8                     0.8     chemprot             3
# 29                  0.8                     0.8     chemprot             4
# 28                  0.8                     0.8     chemprot             6
# 0                   0.8                     0.8     chemprot             7
# 2                   0.8                     0.8     chemprot             2
#
#     confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 39               0.95               1.00             0.330451
# 23               0.95               1.00             0.351415
# 19               1.00               0.95             0.352286
# 8                1.00               0.80             0.364479
# 29               1.00               0.90             0.366843
# 28               0.95               0.95             0.403173
# 0                1.00               1.00             0.418227
# 2                0.85               0.95             0.443359
#
#     global_accuracy_on_valid_data  new_global_accuracy_on_valid  \
# 39                       0.529399                      0.330451
# 23                       0.529399                      0.351415
# 19                       0.529399                      0.352286
# 8                        0.529399                      0.364479
# 29                       0.529399                      0.366843
# 28                       0.529399                      0.403173
# 0                        0.529399                      0.418227
# 2                        0.529399                      0.443359
#
#     valid_global_data_size  new_valid_global_data_size  \
# 39                   13742                       16075
# 23                   13742                       16075
# 19                   13742                       16075
# 8                    13742                       16075
# 29                   13742                       16075
# 28                   13742                       16075
# 0                    13742                       16075
# 2                    13742                       16075
#
#                                              runtimes  optimal_objective_value
# 39  {'snorkel_first_run': 2.5486860275268555, 'sno...                    804.0
# 23  {'snorkel_first_run': 2.413106918334961, 'snor...                    804.0
# 19  {'snorkel_first_run': 2.5703930854797363, 'sno...                    805.0
# 8   {'snorkel_first_run': 2.309006690979004, 'snor...                    804.0
# 29  {'snorkel_first_run': 2.569164991378784, 'snor...                    809.0
# 28  {'snorkel_first_run': 2.4730801582336426, 'sno...                    813.0
# 0   {'snorkel_first_run': 2.5822179317474365, 'sno...                    800.0
# 2   {'snorkel_first_run': 2.3969500064849854, 'sno...                    804.0

# %%
df['dataset_name'].unique()
# Out:
# array(['chemprot'], dtype=object)

# %%
# df_final.to_csv('repaired_results_for_gpt_lfs.csv', index=False)

# %%
df_final.to_csv('repaired_results_for_chemprot.csv', index=False)
