# %%
# from lfs_tree import *
import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)
import pydot
import networkx as nx
from string import Template
import pandas as pd
import glob
import pydot
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
import pickle
from IPython.display import Image, display

# %%
def view_pydot(pdot):
    plt = Image(pdot.create_png())
    display(plt)

def show_trees(directory):
    print(directory)
    treefiles = glob.glob(f'{directory}*tree_*')
    num_trees_per_strat = len(treefiles)/2
    for i in range(0, int(num_trees_per_strat)):
        for f in glob.glob(f'{directory}*tree_*_{i}*'):
            file = open(f)
            dot_string = file.read()
            print(f)
            graph = pydot.graph_from_dot_data(dot_string)[0]
            view_pydot(graph)
            print('\n')
def show_stats(directory):
    f = glob.glob(f'{directory}*experiment_stats')[0]
    print(f)
#                                 experiment_stats
#     file = open('../intro_example/experiment_stats')
    df = pd.read_csv(f)
    print(df)
    return df

def show_user_inputs(directory):
    f = glob.glob(f'{directory}sampled*')[0]
    df = pd.read_csv(f)
    print(list(df))
    return df[['text', 'expected_label', 'model_pred', 'id']].sort_values(by=['text'])

def view_repair_bookkeeping_results(directory):
    print(glob.glob(f'{directory}*book_keeping_dict*'))
    f = glob.glob(f'{directory}*book_keeping_dict*')[0]
#               20230921002723fix_book_keeping_dict.pkl
    with open(f, 'rb') as file:
        # Load the object from the file
        loaded_object = pickle.load(file)
#         print("Object loaded successfully:")
#         print(loaded_object)
    return loaded_object

# %%
dirs = glob.glob('../../rbbm_src/experiment_results_folders/')
print(dirs)
# Out:
# ['../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929063425', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929134252', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929065314', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929114121', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929050700', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929132033', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929110310', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929122523', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929120142', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929054646', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929113350', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929122852', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929133834', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929074725', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929123225', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929125458', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929053934', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929055447', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929085012', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929115615', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929114947', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929113731', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929132730', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929073621', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929090048', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929055034', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929135325', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929043406', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929063058', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929072925', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929070348', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929103910', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929083828', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929084210', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929134704', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929092621', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929044101', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929112649', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929085426', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929093322', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929092953', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929132359', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929083121', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929045627', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929133102', '../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929094424', '../../rbbm_src/experiment_results_folders/ ...

# %%
df = pd.concat([show_stats(f+'/') for f in dirs])
# Out:
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929063425/20230929063425_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain         3.786       152.401                2.733333
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0               20              0.5              10                 10
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       0.9                    0.3                0.704
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929134252/20230929134252_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         5.685       177.653               16.533333              160
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              80                 80            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                   0.75                0.741              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929065314/20230929065314_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         5.704       175.781               16.533333              160
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              80                 80            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                   0.75                0.741              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929114121/20230929114121_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain        36.144        158.22                5.266667
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0               80              0.5              40                 40
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307     0.975                  0.575                0.731
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929050700/20230929050700_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive        45.008        195.26               36.666667              320
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5             160                160            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                  0.769                0.766              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929132033/20230929132033_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         1.285       150.802                     3.0               20
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              10                 10            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                    0.4                0.712              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929110310/20230929110310_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain       952.805       165.204                    10.2
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0              320              0.5             160                160
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       1.0                  0.794                0.802
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929122523/20230929122523_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain         3.789       149.596                2.733333
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0               20              0.5              10                 10
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       0.9                    0.3                0.704
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929120142/20230929120142_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain       959.276       165.699                    10.2
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0              320              0.5             160                160
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       1.0                  0.794                0.802
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929054646/20230929054646_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive          3.55       164.114                8.866667               80
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              40                 40            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                   0.55                 0.73              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929113350/20230929113350_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain        11.348       153.023                3.466667
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0               40              0.5              20                 20
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       0.9                   0.35                0.705
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929122852/20230929122852_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         1.976       154.891                5.066667               40
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              20                 20            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                    0.5                0.719              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929133834/20230929133834_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain        36.521       160.154                5.266667
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0               80              0.5              40                 40
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307     0.975                  0.575                0.731
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929074725/20230929074725_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain        36.723       156.965                5.266667
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0               80              0.5              40                 40
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307     0.975                  0.575                0.731
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929123225/20230929123225_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain        11.225       153.318                3.466667
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0               40              0.5              20                 20
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       0.9                   0.35                0.705
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929125458/20230929125458_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive        45.108       193.352               36.666667              320
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5             160                160            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                  0.769                0.766              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929053934/20230929053934_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         1.966       153.921                5.066667               40
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              20                 20            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                    0.5                0.719              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929055447/20230929055447_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         5.684       177.619               16.533333              160
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              80                 80            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                   0.75                0.741              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929085012/20230929085012_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         5.743       179.358               16.533333              160
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              80                 80            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                   0.75                0.741              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929115615/20230929115615_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         46.42       194.249               36.666667              320
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5             160                160            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                  0.769                0.766              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929114947/20230929114947_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain       153.825       165.389                7.066667
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0              160              0.5              80                 80
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       1.0                  0.713                 0.78
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929113731/20230929113731_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         3.519       165.248                8.866667               80
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              40                 40            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                   0.55                 0.73              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929132730/20230929132730_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         1.945       154.053                5.066667               40
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              20                 20            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                    0.5                0.719              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929073621/20230929073621_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         1.939       156.316                5.066667               40
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              20                 20            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                    0.5                0.719              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929090048/20230929090048_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive        44.944       191.166               36.666667              320
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5             160                160            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                  0.769                0.766              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929055034/20230929055034_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain        36.146       156.626                5.266667
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0               80              0.5              40                 40
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307     0.975                  0.575                0.731
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929135325/20230929135325_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive        45.372       194.424               36.666667              320
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5             160                160            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                  0.769                0.766              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929043406/20230929043406_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         1.272       151.688                     3.0               20
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              10                 10            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                    0.4                0.712              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929063058/20230929063058_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         1.284       151.547                     3.0               20
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              10                 10            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                    0.4                0.712              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929072925/20230929072925_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         1.277       149.926                     3.0               20
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              10                 10            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                    0.4                0.712              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929070348/20230929070348_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         44.61       194.814               36.666667              320
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5             160                160            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                  0.769                0.766              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929103910/20230929103910_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         3.527       163.871                8.866667               80
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              40                 40            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                   0.55                 0.73              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929083828/20230929083828_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain        12.052       152.761                3.466667
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0               40              0.5              20                 20
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       0.9                   0.35                0.705
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929084210/20230929084210_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         3.553       164.606                8.866667               80
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              40                 40            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                   0.55                 0.73              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929134704/20230929134704_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain       152.189       160.886                7.066667
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0              160              0.5              80                 80
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       1.0                  0.713                 0.78
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929092621/20230929092621_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         1.273       155.563                     3.0               20
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              10                 10            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                    0.4                0.712              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929044101/20230929044101_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive          1.94       160.658                5.066667               40
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              20                 20            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                    0.5                0.719              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929112649/20230929112649_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain         3.788       150.702                2.733333
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0               20              0.5              10                 10
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       0.9                    0.3                0.704
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929085426/20230929085426_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain       153.949       161.088                7.066667
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0              160              0.5              80                 80
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       1.0                  0.713                 0.78
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929093322/20230929093322_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         1.949       155.381                5.066667               40
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              20                 20            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                    0.5                0.719              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929092953/20230929092953_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain         3.821        150.42                2.733333
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0               20              0.5              10                 10
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       0.9                    0.3                0.704
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929132359/20230929132359_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain          3.81       151.704                2.733333
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0               20              0.5              10                 10
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       0.9                    0.3                0.704
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929083121/20230929083121_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# ...
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929124412/20230929124412_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive          5.69         180.7               16.533333              160
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              80                 80            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                   0.75                0.741              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929053604/20230929053604_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain         3.778       152.096                2.733333
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0               20              0.5              10                 10
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       0.9                    0.3                0.704
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929130022/20230929130022_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain        958.73       166.541                    10.2
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0              320              0.5             160                160
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       1.0                  0.794                0.802
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929133444/20230929133444_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         3.524       166.133                8.866667               80
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              40                 40            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                   0.55                 0.73              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929135851/20230929135851_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain       956.459       165.101                    10.2
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0              320              0.5             160                160
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       1.0                  0.794                0.802
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929094844/20230929094844_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         5.668       177.111               16.533333              160
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              80                 80            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                   0.75                0.741              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929055858/20230929055858_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain       153.362       161.611                7.066667
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0              160              0.5              80                 80
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       1.0                  0.713                 0.78
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929080744/20230929080744_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain       954.131       166.109                    10.2
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0              320              0.5             160                160
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       1.0                  0.794                0.802
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929050036/20230929050036_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain       153.727       162.416                7.066667
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0              160              0.5              80                 80
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       1.0                  0.713                 0.78
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929053236/20230929053236_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         1.285       151.783                     3.0               20
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              10                 10            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                    0.4                0.712              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929094037/20230929094037_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         3.514       163.977                8.866667               80
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              40                 40            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                   0.55                 0.73              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929074340/20230929074340_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         3.529       161.562                8.866667               80
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              40                 40            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                   0.55                 0.73              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929122154/20230929122154_experiment_stats
#    strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  user_input_size  \
# 0  naive         1.275       153.816                     3.0               20
#
#    complaint_ratio  num_complaints  num_confirmations  global_accuracy  \
# 0              0.5              10                 10            0.307
#
#    fix_rate  confirm_preserve_rate  new_global_accuracy  prev_signaled_cnt  \
# 0       1.0                    0.4                0.712              17674
#
#    new_signaled_cnt  num_functions  deletion_factor  post_fix_num_funcs  \
# 0             17674             30              0.0                  30
#
#    num_of_funcs_processed_by_algo  complaint_reached_max  confirm_reached_max  \
# 0                              30                  False                False
#
#   lf_source  retrain_after_percent  retrain_accuracy_thresh  \
# 0     intro                      1                        1
#
#    load_funcs_from_pickle  pre_deletion_threshold
# 0                    True                     0.0
# ../../rbbm_src/experiment_results_folders/experiment_lf_scalability_20230929100448/20230929100448_experiment_stats
#               strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0  information_gain       956.991       164.869                    10.2
#
#    user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# 0              320              0.5             160                160
#
#    global_accuracy  fix_rate  confirm_preserve_rate  new_global_accuracy  \
# 0            0.307       1.0                  0.794                0.802
#
#    prev_signaled_cnt  new_signaled_cnt  num_functions  deletion_factor  \
# 0              17674             17674             30              0.0
#
#    post_fix_num_funcs  num_of_funcs_processed_by_algo  complaint_reached_max  \
# 0                  30                              30                  False
#
#    confirm_reached_max lf_source  retrain_after_percent  \
# 0                False     intro                      1
#
#    retrain_accuracy_thresh  load_funcs_from_pickle  pre_deletion_threshold
# 0                        1                    True                     0.0

# %%
list(df)
# Out:
# ['strat',
#  'rbbm_runtime',
#  'bbox_runtime',
#  'avg_tree_size_increase',
#  'user_input_size',
#  'complaint_ratio',
#  'num_complaints',
#  'num_confirmations',
#  'global_accuracy',
#  'fix_rate',
#  'confirm_preserve_rate',
#  'new_global_accuracy',
#  'prev_signaled_cnt',
#  'new_signaled_cnt',
#  'num_functions',
#  'deletion_factor',
#  'post_fix_num_funcs',
#  'num_of_funcs_processed_by_algo',
#  'complaint_reached_max',
#  'confirm_reached_max',
#  'lf_source',
#  'retrain_after_percent',
#  'retrain_accuracy_thresh',
#  'load_funcs_from_pickle',
#  'pre_deletion_threshold']
