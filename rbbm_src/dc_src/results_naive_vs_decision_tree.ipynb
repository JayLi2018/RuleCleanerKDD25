# %%
import pandas as pd

# %%
df=pd.read_csv('results.csv')
df.set_index('complaint_size')
df.sort_values('complaint_size')
# Out:
#          strategy  complaint_size     runtime  avg_tree_size_increase
# 0           naive               4    0.244310                     1.0
# 6   decision_tree               4    0.277630                     0.7
# 1           naive              10    0.472887                     3.2
# 7   decision_tree              10    0.749359                     2.1
# 2           naive              20    0.960815                     7.1
# 8   decision_tree              20    2.447916                     4.3
# 3           naive              40    1.846344                    11.3
# 9   decision_tree              40    6.115590                     4.8
# 4           naive             100    4.493171                     9.5
# 10  decision_tree             100   25.450043                     6.6
# 5           naive             200    9.212769                    12.5
# 11  decision_tree             200  132.557469                     8.7
