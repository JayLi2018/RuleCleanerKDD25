# %%
import pandas as pd

# %%
df=pd.read_csv('results_3_variations.csv')
df.set_index('complaint_size')
df.sort_values('complaint_size')
# Out:
#             strategy  complaint_size     runtime avg_size_increase
# 0            optimal               2    0.106450             {0.4}
# 15           optimal               2    0.107984             {0.4}
# 16             naive               2    0.098335             {0.7}
# 17  information gain               2    0.115836             {0.4}
# 2   information gain               2    0.114024             {0.4}
# 1              naive               2    0.096059             {0.7}
# 4              naive               4    0.192560             {2.3}
# 5   information gain               4    0.262832             {0.7}
# 20  information gain               4    0.260733             {0.7}
# 19             naive               4    0.189909             {2.5}
# 18           optimal               4    0.351509             {0.7}
# 3            optimal               4    0.351146             {0.7}
# 6            optimal               6    2.271892             {1.7}
# ...
