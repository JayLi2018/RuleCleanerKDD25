# %%
import pandas as pd

# %%
df=pd.read_csv('results_overall.csv')
df.set_index('complaint_size')
df.sort_values('complaint_size')
# Out:
#            strategy  complaint_size     runtime avg_size_increase  \
# 0  information gain              19    1.622342             {3.5}
# 1  information gain              37    4.463686             {7.8}
# 2  information gain              54   11.362431            {12.5}
# 3  information gain              72   19.772022            {14.9}
# 4  information gain              89   27.174050            {19.0}
# 5  information gain             107   31.681361            {18.9}
# 6  information gain             125   48.701305            {23.3}
# 7  information gain             142   58.930909            {26.1}
# 8  information gain             160   85.814255            {31.8}
# 9  information gain             177  102.192876            {35.1}
#
#    dirty_preserving_rate  dirty_fix_rate  clean_preserving_rate
# 0               0.500000             0.0               0.750000
# 1               0.333333             0.0               0.812500
# ...

# %%
# dirty_preserving: the ones that Holoclean correctly fixed and after the repairs it is still being fixed
# dirty_fix: the ones Holoclean didnt fix but should be fixed, this is the number of those complaints
    # getting fixed by Holoclean after repairs over the complaint set
# clean_preserving: the rate of which the tuples should not be fixed and after the repairs it is not
    # being fixed
    
    # dirty_input: currently clean, but should be dirty
    # clean_input: currently dirty, but should be clean
    
dirty_preserving= confimred_dirty_cnt/len(confirm_dirty)
