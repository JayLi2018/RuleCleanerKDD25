# %%
import pickle
import glob

# %%
# res_no_lf_only = []
# res_no_lf_and_no_non_abstain = []
# res_dfs_no_lf_and_no_non_abstain = []
# res_dfs_no_lf_only=[]
res = []

# %%
# for f in glob.glob('Oct15_night_run/*.pkl'):
#     with open(f, 'rb') as resf:
#         res.append(pickle.load(resf))
        
# for f in glob.glob('oct-15*.pkl'):
#     with open(f, 'rb') as resf:
#         res.append(pickle.load(resf))

# f_no_new_lf_and_no_non_abstain = set()

# for f in glob.glob('testing_agnews-no_new_lf_and_no_non_abstain*.pkl'):
#     f_no_new_lf_and_no_non_abstain.add(f)
#     with open(f, 'rb') as resf:
#         res_no_lf_and_no_non_abstain.append(pickle.load(resf))

        
# for f in glob.glob('testing_agnews-no_new_lf*.pkl'):
#     if(f not in f_no_new_lf_and_no_non_abstain):
#         with open(f, 'rb') as resf:
#             res_no_lf_only.append(pickle.load(resf))


for f in glob.glob('Oct17_milp_other_params/*.pkl'):
    with open(f, 'rb') as resf:
        res.append(pickle.load(resf))

# %%
# f_no_new_lf_and_no_non_abstain

# %%
import pandas as pd

# %%
def max_depth(node):
    if node is None:
        return 0
    left_depth = max_depth(node.left)
    right_depth = max_depth(node.right)
    
    return 1 + max(left_depth, right_depth)

# %%
# for r in res_no_lf_and_no_non_abstain:
#     df_r = pd.DataFrame([r['summary']])
#     r_details = r['fix_details']
#     tree_depth_list = [max_depth(r_details[i]['rule'].root) for i in list(r_details)]
#     df_r['avg_tree_depth'] = sum(tree_depth_list) / len(tree_depth_list)
#     df_r['tree_cnt_after_fix'] = len(r['fix_details'])
#     df_r['avg_tree_size'] = sum([x['rule'].size for x in r['fix_details'].values()]) / len(r['fix_details'])
#     df_r['min_non_abstain_thresh'] = 'NAN'
#     df_r['no_abstain_thresh'] = 'yes'
#     res_dfs_no_lf_and_no_non_abstain.append(df_r)

# %%
# for r in res_no_lf_only:
#     df_r = pd.DataFrame([r['summary']])
#     r_details = r['fix_details']
#     tree_depth_list = [max_depth(r_details[i]['rule'].root) for i in list(r_details)]
#     df_r['avg_tree_depth'] = sum(tree_depth_list) / len(tree_depth_list)
#     df_r['tree_cnt_after_fix'] = len(r['fix_details'])
#     df_r['avg_tree_size'] = sum([x['rule'].size for x in r['fix_details'].values()]) / len(r['fix_details'])
# #     df_r['min_non_abstain_thresh'] = 'NAN'
#     df_r['no_abstain_thresh'] = 'No'
#     res_dfs_no_lf_only.append(df_r)

# %%
res_dfs = []

# %%
for r in res:
    df_r = pd.DataFrame([r['summary']])
    r_details = r['fix_details']
    tree_depth_list = [max_depth(r_details[i]['rule'].root) for i in list(r_details)]
    df_r['avg_tree_depth'] = sum(tree_depth_list) / len(tree_depth_list)
    df_r['tree_cnt_after_fix'] = len(r['fix_details'])
    df_r['avg_tree_size'] = sum([x['rule'].size for x in r['fix_details'].values()]) / len(r['fix_details'])
    df_r['runtime_total'] = sum([v for v in r['summary']['runtimes'].values()])
    df_r['repair_time'] = r['summary']['runtimes']['repair_time']
    res_dfs.append(df_r)

# %%
# df_no_lf_only = pd.concat(res_dfs_no_lf_only)

# %%
# df_no_lf_only

# %%
# df_no_lf_and_no_non_abstain = pd.concat(res_dfs_no_lf_and_no_non_abstain)

# %%
# df_no_lf_and_no_non_abstain

# %%
# df_full = pd.concat([df_no_lf_and_no_non_abstain, df_no_lf_only])

# %%
df = pd.concat(res_dfs)

# %%
df
# Out:
#     before_fix_global_accuracy  user_input_size  lf_acc_thresh  \
# 0                     0.543700               20            0.3
# 0                     0.552917               20            0.3
# 0                     0.812358               20            0.3
# 0                     0.427780               20            0.3
# 0                     0.708314               20            0.3
# ..                         ...              ...            ...
# 0                     0.427780               20            0.5
# 0                     0.708314               20            0.5
# 0                     0.534586               20            0.5
# 0                     0.851912               20            0.5
# 0                     0.544092               20            0.5
#
#     instance_acc_thresh  min_non_abstain_thresh         dataset_name  \
# 0                   0.3                     0.3               agnews
# 0                   0.3                     0.3                plots
# 0                   0.3                     0.3  physician_professor
# 0                   0.3                     0.3                 imdb
# 0                   0.3                     0.3             fakenews
# ..                  ...                     ...                  ...
# 0                   0.7                     0.3                 imdb
# 0                   0.7                     0.3             fakenews
# 0                   0.7                     0.3                 yelp
# 0                   0.7                     0.3    painter_architect
# 0                   0.7                     0.3               tweets
#
#     random_state  confirm_prev_rate  complain_fix_rate  new_global_accuracy  \
# 0            123                0.7                0.4             0.528967
# 0            123                1.0                0.3             0.532783
# 0            123                0.8                0.5             0.823482
# 0            123                1.0                0.2             0.602040
# 0            123                1.0                0.4             0.737725
# ..           ...                ...                ...                  ...
# 0            123                1.0                1.0             0.541340
# 0            123                1.0                0.4             0.759788
# 0            123                1.0                0.8             0.613797
# 0            123                0.9                0.5             0.855018
# 0            123                0.4                1.0             0.424800
#
#     ...  new_global_accuracy_on_valid  valid_global_data_size  \
# 0   ...                      0.644361                   40276
# 0   ...                      0.656489                    1461
# 0   ...                      0.835009                   53357
# 0   ...                      0.713351                   26729
# 0   ...                      0.740756                   42444
# ..  ...                           ...                     ...
# 0   ...                      0.567919                   26729
# 0   ...                      0.769724                   42444
# 0   ...                      0.712172                   25590
# 0   ...                      0.898180                   11597
# 0   ...                      0.448565                   10528
#
#     new_valid_global_data_size  \
# 0                        49255
# 0                         1572
# 0                        53724
# 0                        42198
# 0                        44055
# ..                         ...
# 0                        47660
# 0                        43665
# 0                        32707
# 0                        11648
# 0                        10868
#
#                                              runtimes optimal_objective_value  \
# 0   {'snorkel_first_run': 17.32433772087097, 'snor...                    35.0
# 0   {'snorkel_first_run': 0.8955483436584473, 'sno...                    30.0
# 0   {'snorkel_first_run': 44.51265859603882, 'snor...                    39.0
# 0   {'snorkel_first_run': 10.363841533660889, 'sno...                    33.0
# 0   {'snorkel_first_run': 19.823271989822388, 'sno...                    32.0
# ..                                                ...                     ...
# 0   {'snorkel_first_run': 10.330240488052368, 'sno...                    43.0
# 0   {'snorkel_first_run': 21.371337890625, 'snorke...                    37.0
# 0   {'snorkel_first_run': 7.612982273101807, 'snor...                    46.0
# 0   {'snorkel_first_run': 4.402768135070801, 'snor...                    32.0
# 0   {'snorkel_first_run': 4.566656827926636, 'snor...                    61.0
#
#     avg_tree_depth  tree_cnt_after_fix  avg_tree_size  runtime_total  \
# 0         5.333333                   9       9.666667      50.328821
# 0         4.700000                  10       9.000000       3.800385
# 0         3.777778                  18       7.444444      97.479503
# 0         4.857143                   7       9.285714      38.930604
# 0         3.636364                  11       7.000000      53.383394
# ..             ...                 ...            ...            ...
# 0         5.428571                   7      11.571429      41.109071
# 0         4.181818                  11       8.636364      76.202868
# 0         6.000000                   8      12.250000      29.087979
# 0         4.300000                  10       8.400000      12.421131
# 0         5.250000                  16      10.750000      16.160609
#
#     repair_time
# 0      1.173011
# 0      0.697268
# 0      1.362399
# 0      4.015136
# 0      6.584057
# ..          ...
# 0     10.345547
# 0     15.178044
# 0      3.250429
# 0      0.970843
# 0      0.720338
#
# [143 rows x 21 columns]

# %%
list(df)
# Out:
# ['before_fix_global_accuracy',
#  'user_input_size',
#  'lf_acc_thresh',
#  'instance_acc_thresh',
#  'min_non_abstain_thresh',
#  'dataset_name',
#  'random_state',
#  'confirm_prev_rate',
#  'complain_fix_rate',
#  'new_global_accuracy',
#  'global_accuracy_on_valid_data',
#  'new_global_accuracy_on_valid',
#  'valid_global_data_size',
#  'new_valid_global_data_size',
#  'runtimes',
#  'optimal_objective_value',
#  'avg_tree_depth',
#  'tree_cnt_after_fix',
#  'avg_tree_size',
#  'runtime_total',
#  'repair_time']

# %%
ordered_cols = [
 'dataset_name',
'before_fix_global_accuracy',
  'new_global_accuracy',
 'user_input_size',
    'repair_time',
 'min_non_abstain_thresh',
 'random_state',
 'confirm_prev_rate',
 'complain_fix_rate',
 'global_accuracy_on_valid_data',
 'new_global_accuracy_on_valid',
 'valid_global_data_size',
 'new_valid_global_data_size',
 'runtimes',
 'optimal_objective_value',
 'avg_tree_depth',
 'tree_cnt_after_fix',
 'avg_tree_size',
 'runtime_total',
 'lf_acc_thresh',
 'instance_acc_thresh']

# %%
df_ordered = df[ordered_cols].sort_values(by=['dataset_name','user_input_size','random_state'])

# %%
df_ordered
# Out:
#    dataset_name  before_fix_global_accuracy  new_global_accuracy  \
# 0        agnews                    0.543700             0.528967
# 0        agnews                    0.543700             0.568150
# 0        agnews                    0.543700             0.619167
# 0        agnews                    0.543700             0.573783
# 0        agnews                    0.543700             0.623850
# ..          ...                         ...                  ...
# 0          yelp                    0.534586             0.575588
# 0          yelp                    0.534586             0.641255
# 0          yelp                    0.534586             0.527260
# 0          yelp                    0.534586             0.648739
# 0          yelp                    0.534586             0.613797
#
#     user_input_size  repair_time  min_non_abstain_thresh  random_state  \
# 0                20     1.173011                     0.3           123
# 0                20     1.661256                     0.5           123
# 0                20     2.406556                     0.7           123
# 0                20     1.116440                     0.3           123
# 0                20     1.552946                     0.5           123
# ..              ...          ...                     ...           ...
# 0                20     3.495242                     0.7           123
# 0                20     3.859351                     0.3           123
# 0                20     3.228012                     0.5           123
# 0                20     3.745990                     0.7           123
# 0                20     3.250429                     0.3           123
#
#     confirm_prev_rate  complain_fix_rate  global_accuracy_on_valid_data  ...  \
# 0                 0.7                0.4                       0.809961  ...
# 0                 0.9                0.5                       0.809961  ...
# 0                 0.7                0.7                       0.809961  ...
# 0                 0.7                0.7                       0.809961  ...
# 0                 0.5                0.5                       0.809961  ...
# ..                ...                ...                            ...  ...
# 0                 0.7                0.4                       0.792771  ...
# 0                 0.9                0.3                       0.792771  ...
# 0                 0.5                0.7                       0.792771  ...
# 0                 0.8                0.4                       0.792771  ...
# 0                 1.0                0.8                       0.792771  ...
#
#     valid_global_data_size  new_valid_global_data_size  \
# 0                    40276                       49255
# 0                    40276                       53851
# 0                    40276                       60000
# 0                    40276                       47972
# 0                    40276                       59731
# ..                     ...                         ...
# 0                    25590                       37949
# 0                    25590                       34159
# 0                    25590                       34300
# 0                    25590                       37949
# 0                    25590                       32707
#
#                                              runtimes optimal_objective_value  \
# 0   {'snorkel_first_run': 17.32433772087097, 'snor...                    35.0
# 0   {'snorkel_first_run': 17.72576665878296, 'snor...                    75.0
# 0   {'snorkel_first_run': 17.23610281944275, 'snor...                   115.0
# 0   {'snorkel_first_run': 17.722903728485107, 'sno...                    36.0
# 0   {'snorkel_first_run': 17.294842958450317, 'sno...                    75.0
# ..                                                ...                     ...
# 0   {'snorkel_first_run': 7.705400228500366, 'snor...                    93.0
# 0   {'snorkel_first_run': 8.260480403900146, 'snor...                    34.0
# 0   {'snorkel_first_run': 8.287550926208496, 'snor...                    53.0
# 0   {'snorkel_first_run': 8.193096399307251, 'snor...                    93.0
# 0   {'snorkel_first_run': 7.612982273101807, 'snor...                    46.0
#
#     avg_tree_depth  tree_cnt_after_fix  avg_tree_size  runtime_total  \
# 0         5.333333                   9       9.666667      50.328821
# 0         7.555556                   9      14.555556      59.306898
# 0         7.333333                   9      14.111111      61.024909
# 0         5.333333                   9       9.888889      57.265694
# 0         7.333333                   9      13.888889      57.555127
# ..             ...                 ...            ...            ...
# 0         7.125000                   8      14.500000      30.931980
# 0         5.000000                   8       9.250000      27.659948
# 0         6.500000                   8      12.500000      29.506541
# 0         7.125000                   8      14.250000      32.463632
# 0         6.000000                   8      12.250000      29.087979
#
#     lf_acc_thresh  instance_acc_thresh
# 0             0.3                  0.3
# 0             0.3                  0.3
# 0             0.3                  0.3
# 0             0.3                  0.5
# 0             0.3                  0.5
# ..            ...                  ...
# 0             0.5                  0.3
# 0             0.5                  0.5
# 0             0.5                  0.5
# 0             0.5                  0.5
# 0             0.5                  0.7
#
# [143 rows x 21 columns]

# %%
result_repair_time = df_ordered.groupby(['dataset_name', 'user_input_size']).agg(
    mean_value=('repair_time', 'mean'),
    variance_value=('repair_time', 'std')
).reset_index()

# %%
result_repair_time
# Out:
#           dataset_name  user_input_size  mean_value  variance_value
# 0               agnews               20    1.585499        0.445201
# 1             fakenews               20   14.042862        4.962771
# 2                 imdb               20    7.350457        2.178183
# 3    painter_architect               20    1.355195        0.492105
# 4  physician_professor               20    2.590561        1.082004
# 5                plots               20    1.138775        0.320077
# 6                 spam               20    1.347415        0.268817
# 7               tweets               20    0.904245        0.208037
# 8                 yelp               20    3.651438        0.649825

# %%
# result_repair_time.to_csv('repair_times.csv', index=False)

# %%
df_ordered.to_csv('df_solver_other_params.csv', index=False)

# %%
# df_inst_acc_on_all.to_csv('df_inst_acc_on_all_agnews.csv', index=False)

# %%
# df_res.to_csv('df_new_solver_result_summary_new_datasets.csv', index=False)
# df_res.to_csv('df_new_solver_oct-15_agnews.csv', index=False)
# df_full.to_csv('df_new_solver_with_and_without_non_abstain.csv', index=False)

# %%
# import concurrent.futures
# import time

# def run_with_params(params):
#     # Example of a function that might run long
#     time.sleep(params)  # Simulate work
#     return f"Finished params: {params}"

# def test_params_with_timeout(params_list, time_limit_minutes):
#     time_limit_seconds = time_limit_minutes * 60
#     results = []

#     with concurrent.futures.ThreadPoolExecutor() as executor:
#         for params in params_list:
#             future = executor.submit(run_with_params, params)
#             try:
#                 result = future.result(timeout=time_limit_seconds)
#                 print(result)
#                 results.append(result)
#             except concurrent.futures.TimeoutError:
#                 print(f"Params {params} exceeded time limit, moving to next.")
    
#     return results

# # Example usage
# params_list = [1, 5, 10, 2]  # Parameters that would be passed to the function
# results = test_params_with_timeout(params_list, time_limit_minutes=0.1)

# %%
# max_depth(test_tree_rule.root)

# %%
import pydot
from IPython.display import Image, display

# %%
# dot_string = test_tree_rule.gen_dot_string('')
# graph = pydot.graph_from_dot_data(dot_string)[0]
# plt = Image(graph.create_png())
# display(plt)

# %%
# test_tree_rule.size
