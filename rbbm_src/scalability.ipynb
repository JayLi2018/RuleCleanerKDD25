# %%
import pandas as pd
import glob

# %%
def show_stats(directory):
    f = glob.glob(f'{directory}*experiment_stats')[0]
    print(f)

# %%
f = glob.glob('experiment_results_folders/experiment_lf_scalability_*/*experiment_stats')

# %%
len(f)
# Out:
# 90

# %%
df = pd.concat([pd.read_csv(x) for x in f])

# %%
df
# Out:
#                strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0   information_gain         3.786       152.401                2.733333
# 0              naive         5.704       175.781               16.533333
# 0   information_gain        36.144       158.220                5.266667
# 0              naive        45.008       195.260               36.666667
# 0   information_gain       952.805       165.204               10.200000
# ..               ...           ...           ...                     ...
# 0              naive         1.285       151.783                3.000000
# 0              naive         3.514       163.977                8.866667
# 0              naive         3.529       161.562                8.866667
# 0              naive         1.275       153.816                3.000000
# 0   information_gain       956.991       164.869               10.200000
#
#     user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# ...

# %%
df['dataset_name']='enron'

# %%
df
# Out:
#                strat  rbbm_runtime  bbox_runtime  avg_tree_size_increase  \
# 0   information_gain         3.786       152.401                2.733333
# 0              naive         5.704       175.781               16.533333
# 0   information_gain        36.144       158.220                5.266667
# 0              naive        45.008       195.260               36.666667
# 0   information_gain       952.805       165.204               10.200000
# ..               ...           ...           ...                     ...
# 0              naive         1.285       151.783                3.000000
# 0              naive         3.514       163.977                8.866667
# 0              naive         3.529       161.562                8.866667
# 0              naive         1.275       153.816                3.000000
# 0   information_gain       956.991       164.869               10.200000
#
#     user_input_size  complaint_ratio  num_complaints  num_confirmations  \
# ...

# %%
df.to_csv('enrone_scalability)
