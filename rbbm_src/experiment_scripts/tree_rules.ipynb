# %%
import pickle

# %%
with open('/home/opc/author/RBBM/rbbm_src/labelling_func_src/src/pickled_funcs_720.pkl', 'rb') as file:
    funcs = pickle.load(file)

# %%
funcs
# Out:
# [pred:keyword_predicate-word-(check), id:1
#  parent_id: NaN
#
#
#  	label:-1, id: 2
#  parent_id: 1
#  1:[]
#  0:[]
#
#
#  	label:0, id: 3
#  parent_id: 1
#  1:[]
#  0:[]
#  ,
#  pred:keyword_predicate-word-(channel), id:1
#  parent_id: NaN
#
#
#  	label:-1, id: 2
#  parent_id: 1
#  1:[]
#  0:[]
#
#
#  	label:0, id: 3
#  parent_id: 1
#  1:[]
#  0:[]
#  ,
#  pred:keyword_predicate-word-(hey), id:1
#  parent_id: NaN
#
#
#  	label:-1, id: 2
#  parent_id: 1
#  1:[]
#  0:[]
#
#
#  	label:0, id: 3
#  parent_id: 1
#  1:[]
#  0:[]
#  ,
#  pred:keyword_predicate-word-(guys), id:1
#  parent_id: NaN
#
#
#  	label:-1, id: 2
#  parent_id: 1
#  1:[]
#  0:[]
#
#
#  	label:0, id: 3
#  parent_id: 1
#  1:[]
#  0:[]
#  ,
#  pred:keyword_predicate-word-(new), id:1
#  parent_id: NaN
#
#
#  	label:-1, id: 2
#  parent_id: 1
#  1:[]
#  0:[]
#
#
#  	label:0, id: 3
#  parent_id: 1
#  1:[]
#  0:[]
#  ,
#  pred:keyword_predicate-word-(please), id:1
#  parent_id: NaN
#
#
#  	label:-1, id: 2
#  parent_id: 1
# ...
