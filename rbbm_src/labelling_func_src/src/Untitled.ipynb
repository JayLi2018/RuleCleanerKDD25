# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('../../predictions_shakira.csv')

# %%
list(df)
# Out:
# ['COMMENT_ID', 'AUTHOR', 'DATE', 'text', 'label', 'model_pred', 'vectors']

# %%
df_sample = df[['text', 'label', 'model_pred']]

# %%
df_sample
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              text  \
# ...
