# %%
import pandas as pd
import random

# %%
df_tax=pd.read_csv('../../../../tax.csv')

# %%
df_tax.head()
# Out:
#        FName        LName Gender  AreaCode    Phone           City State  \
# 0      Keiko         Noye      F       720  1000000           COMO    CO
# 1      Jilei  Anastasakis      M       605  1000000          FAITH    SD
# 2     Harlan    Macrosson      M       301  1000000  JARRETTSVILLE    MD
# 3       Tyre         Luff      M       971  1000000      BROADBENT    OR
# 4  Toshimasa       Illies      M       715  1000000        MADISON    WI
#
#      Zip MaritalStatus HasChild  Salary      Rate  SingleExemp  MarriedExemp  \
# 0  80432             S        Y   20000  4.630000            0             0
# 1  57626             M        Y   96000  0.000000            0             0
# 2  21084             M        Y   42500  4.750000            0          4800
# 3  97414             M        Y   61500  9.000000            0           318
# 4  53793             M        N   64000  5.558413            0          1400
#
#    ChildExemp
# 0           0
# 1           0
# 2        2400
# ...

# %%
len(df_tax)
# Out:
# 1000000

# %%
list(df_tax['State'].unique())
# Out:
# ['CO',
#  'SD',
#  'MD',
#  'OR',
#  'WI',
#  'AR',
#  'PR',
#  'DC',
#  'NY',
#  'TX',
#  'IL',
#  'NH',
#  'RI',
#  'NV',
#  'AL',
#  'NJ',
#  'WA',
#  'GA',
#  'SC',
#  'MI',
#  'CA',
#  'LA',
#  'OK',
#  'MS',
#  'AZ',
#  'NM',
#  'NC',
#  'VA',
#  'KY',
#  'VT',
#  'PA',
#  'KS',
#  'OH',
#  'MA',
#  'DE',
#  'IA',
#  'IN',
#  'NE',
#  'ID',
#  'AK',
#  'MO',
#  'CT',
#  'WY',
#  'ND',
#  'WV',
#  'UT',
#  'HI',
#  'MT',
#  'TN',
#  'MN',
#  'ME',
#  'FL']

# %%
df_sample=df_tax.sample(2000)
# df_sample=df_sample.reset_index()
df_sample['_tid_'] = range(len(df_sample))
df_sample['is_dirty'] = 'False'

# %%
df_sample.head()
# Out:
#            FName            LName Gender  AreaCode    Phone            City  \
# 842903    Kerima         DiPasquo      M       351  1001806  NORTH WEYMOUTH
# 325322  Dibyendu           Sohoni      F       505  1006218           RODEO
# 206544    Gareth      d'Alcantara      M       802  1004010   WEST DANVILLE
# 954592   Yinfeng  Michalakopoulos      M       775  1009304       LAS VEGAS
# 529384       Hyo          Murillo      F       307  1010192       ROBERTSON
#
#        State    Zip MaritalStatus HasChild  Salary  Rate  SingleExemp  \
# 842903    MA   2191             S        Y   61000   5.3         3575
# 325322    NM  88056             S        Y    1000   1.7         3300
# 206544    VT   5873             S        Y    4000   3.6         3300
# 954592    NV  89160             M        N   14000   0.0            0
# 529384    WY  82944             M        Y   12500   0.0            0
#
#         MarriedExemp  ChildExemp  _tid_ is_dirty
# ...

# %%
# ids = df_sample[df_sample['Gender']=='F']['_tid_'].tolist()
ids = df_sample[df_sample['State']!='IL']['_tid_'].tolist()

# %%
i=1
row_cnt=len(df_sample)
while(i<=50):
#     specific_value = df.at[df['column_name'] == desired_value, 'other_column']

    row_number = random.choice(CAs_ids)
    print(row_number)
    df_sample.loc[df_sample['_tid_']==row_number, 'State']='IL'
#     df.loc[df['A'] == 2, 'B'] = 10
    df_sample.loc[df_sample['_tid_']==row_number, 'is_dirty']='True'
    print('\n')
    i+=1
# Out:
# 479
#
#
# 55
#
#
# 1372
#
#
# 1794
#
#
# 192
#
#
# 507
#
#
# 776
#
#
# 1827
#
#
# 116
#
#
# 1172
#
#
# 67
#
#
# 1786
#
#
# 783
#
#
# 1956
#
#
# 542
#
#
# 1758
#
#
# 1336
#
#
# 667
#
#
# 629
#
#
# 248
#
#
# 1345
#
#
# 103
#
#
# 584
#
#
# 122
#
#
# 505
#
#
# 485
#
#
# 1071
#
#
# 1195
#
#
# 739
#
#
# 664
#
#
# 877
#
#
# 150
#
#
# 4
#
#
# 879
#
#
# 428
#
#
# 729
#
#
# 1741
#
#
# 599
#
#
# 1942
#
#
# 322
#
#
# 729
#
#
# 1070
#
#
# 1387
#
#
# 2
#
#
# 898
#
#
# 743
#
#
# 1674
#
#
# 1904
#
#
# 1589
#
#
# 221

# %%
df_sample.to_csv('../../../muse/data/mas/tax.csv',index=False, header=False)
