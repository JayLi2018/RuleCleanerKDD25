# %%
# from lfs_tree import *
import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)
import pydot
import networkx as nx
from string import Template
import pandas as pd
import glob
import pydot
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

from IPython.display import Image, display
import matplotlib.pyplot as plt
# from IPython.display import Image, display

# %%
def view_pydot(pdot):
    plt = Image(pdot.create_png())
    display(plt)

def show_trees(directory):
    treefiles = glob.glob(f'{directory}*tree_*')
    num_trees_per_strat = len(treefiles)
    for i in range(0, int(num_trees_per_strat)):
        for f in glob.glob(f'{directory}*tree_*_{i}*'):
            file = open(f)
            dot_string = file.read()
            print(f)
#             print(dot_string)
            graph = pydot.graph_from_dot_data(dot_string)[0]
            view_pydot(graph)
            print('\n')
            
def show_stats(directory):
    fs = glob.glob(f'{directory}*experiment_stats')
    dfs = []
    for f in fs:
        one_entry_df = pd.read_csv(f)
        one_entry_df['fname']= f
        dfs.append(one_entry_df)
    df = pd.concat(dfs)
    return df

def determine_shape(x, shape_assignment_dict):
    return shape_assignment_dict[x]

def determine_color(x, color_assignment_dict):
    return color_assignment_dict[x]

def scatter_plots(df, x, y, xlabel, ylabel, title, shape_assignment_dict, color_assignment_dict,
                 first_legend_pos, second_legend_pos, strat_legend_rel_pos, ratio_legend_re_pos):
        
    fig, ax = plt.subplots()
    groups = df.groupby(['strat','complaint_ratio'])
    # Create a scatter plot for each group based on shape and color
    for (strat, ratio), group in groups:
        marker = shape_assignment_dict.get(strat)
        color=color_assignment_dict.get(ratio)
        ax.scatter(group[x], group[y], marker=marker, color=color, label=(strat, ratio))

    # Create separate shape and color legends
    legend_elements_1 = []
    legend_elements_2 = []

    for shape, marker in shape_assignment_dict.items():
        legend_elements_1.append(plt.Line2D([0], [0], marker=marker, color='w', label=shape, markerfacecolor='k'))
    for ratio, color in color_assignment_dict.items():
        legend_elements_2.append(plt.Line2D([0], [0], marker='o', color='w', label=ratio, markerfacecolor=color))

    # Add shape and color legends
    first_legend=ax.legend(handles=legend_elements_1, loc=first_legend_pos, 
                           bbox_to_anchor=strat_legend_rel_pos,
                           title='strategy', 
                           fontsize=13,title_fontsize=14)
    ax.legend(handles=legend_elements_2, loc=second_legend_pos, 
              bbox_to_anchor=ratio_legend_re_pos, title='complaint%',
              fontsize=13, title_fontsize=14)

    ax.add_artist(first_legend)

    ax.set_xlabel(xlabel, fontsize=14)
    ax.set_ylabel(ylabel, fontsize=14)
    ax.set_title(title, fontsize=14)

    plt.show()
    plt.close(fig)

    
def line_plots(df, x, y, xlabel, ylabel, title, color_assignment_dict, legend_pos, group_name,
               group_value, gtype='general',
               ylim=None,
              ):
    fig, ax = plt.subplots()
    df=df[df[group_name]==group_value]
    # Create a scatter plot for each group based on shape and color
    groups = df.groupby(['strat'])
    for strat, group in groups:
        color = color_assignment_dict.get(strat)
        ax.plot(group[x], group[y], color=color, label=strat)
    if(gtype=='accuracy'):
        ax.plot(df[x], df['global_accuracy'], color='blue', label='accuracy_before_fix')
    ax.legend()
    ax.set_xlabel(xlabel, fontsize=14)
    ax.set_ylabel(ylabel, fontsize=14)
    ax.set_title(title, fontsize=14)
    if(ylim):
        ax.set_ylim(ylim)
    plt.savefig(f'graph_pdfs/{title}.pdf', format='pdf')
    plt.show()
    plt.close(fig)
#     return plt

def box_plot(df, x, y, xlabel, ylabel, title, legend_pos, group_name,
               group_value, gtype='general',
               ylim=None,
              ):
    fig, ax = plt.subplots()
    df=df[df[group_name]==group_value]
    # Create a scatter plot for each group based on shape and color
    groups = df.groupby(['strat'])
    for strat, group in groups:
#         color = color_assignment_dict.get(strat)
        ax.boxplot(group[x], group[y], color=color, label=strat)
    if(gtype=='accuracy'):
        ax.plot(df[x], df['global_accuracy'], color='blue', label='accuracy_before_fix')
    ax.legend()
    ax.set_xlabel(xlabel, fontsize=14)
    ax.set_ylabel(ylabel, fontsize=14)
    ax.set_title(title, fontsize=14)
    if(ylim):
        ax.set_ylim(ylim)
    plt.show()
    plt.close(fig)
#     return plt

# %%
# df=show_stats('../exp_710_repeated/')
# df=show_stats('../exp_725_repeated/')
df=show_stats('../exp_727_repeated_320/')
# exp_727_repeated_320

# %%
df_brute = show_stats('../exp_801_repeated/')

# %%
df_brute
# Out:
#          strat   runtime  avg_tree_size_increase  num_complaints  \
# 0  brute_force     0.176                0.933333               4
# 0  brute_force     0.159                1.000000               4
# 0  brute_force     1.455                0.857143               4
# 0  brute_force     0.183                0.000000               4
# 0  brute_force    42.271                1.133333              12
# 0  brute_force     8.931                1.600000              12
# 0  brute_force     0.913                1.142857              12
# 0  brute_force     1.883                0.000000              12
# 0  brute_force   198.129                1.600000              20
# 0  brute_force     0.166                1.333333              20
# 0  brute_force     4.275                1.142857              20
# 0  brute_force    92.923                0.000000              20
# 0  brute_force    23.710                1.666667              28
# 0  brute_force     1.250                1.333333              28
# 0  brute_force  1461.957                1.333333              28
# 0  brute_force     0.231                0.000000              28
# 0  brute_force     0.763                1.400000              36
# 0  brute_force     2.063                1.133333              36
# 0  brute_force    13.013                1.034483              36
# 0  brute_force     3.170                0.000000              36
# 0  brute_force  3623.240                1.533333               8
# 0  brute_force    11.311                1.333333               8
# 0  brute_force     1.979                1.103448               8
# 0  brute_force     4.573                0.000000               8
# 0  brute_force  4677.880                1.800000              24
# 0  brute_force    63.025                1.733333              24
# 0  brute_force    17.539                1.428571              24
# 0  brute_force    10.483                0.000000              24
# 0  brute_force   250.962                2.066667              40
# 0  brute_force    66.952                1.538462              40
# 0  brute_force  1269.928                2.133333              56
# 0  brute_force  5571.624                1.642857              56
# 0  brute_force  4915.917                0.000000              56
# 0  brute_force    15.552                1.666667              72
#
#    confirmation_cnt  global_accuracy  fix_rate  confirm_preserve_rate  \
# 0                36            0.821     0.000                  1.000
# 0                36            0.821     0.500                  0.972
# 0                36            0.821     0.750                  0.778
# 0                36            0.821     1.000                  0.917
# 0                28            0.821     0.417                  0.964
# 0                28            0.821     0.667                  0.893
# 0                28            0.821     0.500                  1.000
# 0                28            0.821     1.000                  0.929
# 0                20            0.821     0.350                  1.000
# 0                20            0.821     0.200                  1.000
# 0                20            0.821     0.350                  0.950
# 0                20            0.821     0.950                  0.950
# 0                12            0.821     0.464                  1.000
# 0                12            0.821     0.071                  0.833
# 0                12            0.821     0.286                  1.000
# 0                12            0.821     0.821                  0.917
# 0                 4            0.821     0.389                  1.000
# 0                 4            0.821     0.639                  1.000
# 0                 4            0.821     0.972                  0.500
# 0                 4            0.821     0.861                  0.500
# 0                72            0.821     0.875                  1.000
# 0                72            0.821     0.375                  1.000
# 0                72            0.821     0.500                  0.986
# 0                72            0.821     1.000                  1.000
# 0                56            0.821     0.292                  0.804
# 0                56            0.821     0.750                  1.000
# 0                56            0.821     0.208                  0.964
# 0                56            0.821     1.000                  0.982
# 0                40            0.821     0.875                  1.000
# 0                40            0.821     0.325                  0.825
# 0                24            0.821     0.393                  1.000
# 0                24            0.821     0.214                  1.000
# 0                24            0.821     1.000                  0.917
# 0                 8            0.821     0.514                  0.875
#
#    new_global_accuracy  prev_signaled_cnt  new_signaled_cnt  num_functions  \
# 0                0.819               1411              1411             30
# 0                0.824               1411              1411             30
# 0                0.703               1411              1317             30
# 0                0.660               1411               818             30
# 0                0.814               1411              1411             30
# 0                0.822               1411              1411             30
# 0                0.800               1411              1292             30
# 0                0.762               1411               516             30
# 0                0.862               1411              1411             30
# 0                0.828               1411              1411             30
# 0                0.823               1411              1358             30
# 0                0.750               1411               553             30
# 0                0.878               1411              1411             30
# 0                0.737               1411              1411             30
# 0                0.771               1411              1181             30
# 0                0.147               1411               893             30
# 0                0.849               1411              1411             30
# 0                0.599               1411              1411             30
# 0                0.420               1411              1335             30
# 0                0.088               1411               776             30
# 0                0.881               1411              1411             30
# 0                0.839               1411              1411             30
# 0                0.815               1411              1403             30
# 0                0.816               1411               653             30
# 0                0.724               1411              1411             30
# 0                0.856               1411              1411             30
# 0                0.789               1411              1292             30
# 0                0.751               1411               442             30
# 0                0.909               1411              1411             30
# 0                0.708               1411              1299             30
# 0                0.875               1411              1411             30
# 0                0.802               1411              1179             30
# 0                0.633               1411               259             30
# 0                0.753               1411              1411             30
#
#    deletion_factor  post_fix_num_funcs  num_of_funcs_processed_by_algo  \
# 0              0.0                  30                              29
# 0              0.3                  30                              29
# 0              0.5                  28                              29
# 0              0.7                  16                              29
# 0              0.0                  30                              29
# 0              0.3                  30                              29
# 0              0.5                  28                              29
# 0              0.7                  12                              29
# 0              0.0                  30                              29
# 0              0.3                  30                              29
# 0              0.5                  28                              29
# 0              0.7                  13                              29
# 0              0.0                  30                              29
# 0              0.3                  30                              29
# 0              0.5                  27                              29
# 0              0.7                  15                              29
# 0              0.0                  30                              29
# 0              0.3                  30                              29
# 0              0.5                  29                              29
# 0              0.7                  13                              29
# 0              0.0                  30                              29
# 0              0.3                  30                              29
# 0              0.5                  29                              29
# 0              0.7                  12                              29
# 0              0.0                  30                              29
# 0              0.3                  30                              29
# 0              0.5                  28                              29
# 0              0.7                  10                              29
# 0              0.3                  30                              29
# 0              0.5                  26                              29
# 0              0.3                  30                              29
# 0              0.5                  28                              29
# 0              0.7                   5                              29
# 0              0.0                  30                              29
#
#    complaint_reached_max  confirm_reached_max  \
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
#
#                                                  fname
# 0  ../exp_801_repeated/20230801213157_experiment_stats
# 0  ../exp_801_repeated/20230801213208_experiment_stats
# 0  ../exp_801_repeated/20230801213218_experiment_stats
# 0  ../exp_801_repeated/20230801213230_experiment_stats
# 0  ../exp_801_repeated/20230801213240_experiment_stats
# 0  ../exp_801_repeated/20230801213338_experiment_stats
# 0  ../exp_801_repeated/20230801213358_experiment_stats
# 0  ../exp_801_repeated/20230801213410_experiment_stats
# 0  ../exp_801_repeated/20230801213422_experiment_stats
# 0  ../exp_801_repeated/20230801213811_experiment_stats
# 0  ../exp_801_repeated/20230801213822_experiment_stats
# 0  ../exp_801_repeated/20230801213837_experiment_stats
# 0  ../exp_801_repeated/20230801214027_experiment_stats
# 0  ../exp_801_repeated/20230801214103_experiment_stats
# 0  ../exp_801_repeated/20230801214115_experiment_stats
# 0  ../exp_801_repeated/20230801220758_experiment_stats
# 0  ../exp_801_repeated/20230801220807_experiment_stats
# 0  ../exp_801_repeated/20230801220819_experiment_stats
# 0  ../exp_801_repeated/20230801220831_experiment_stats
# 0  ../exp_801_repeated/20230801220856_experiment_stats
# 0  ../exp_801_repeated/20230801220908_experiment_stats
# 0  ../exp_801_repeated/20230801231502_experiment_stats
# 0  ../exp_801_repeated/20230801231525_experiment_stats
# 0  ../exp_801_repeated/20230801231538_experiment_stats
# 0  ../exp_801_repeated/20230801231553_experiment_stats
# 0  ../exp_801_repeated/20230802004022_experiment_stats
# 0  ../exp_801_repeated/20230802004142_experiment_stats
# 0  ../exp_801_repeated/20230802004212_experiment_stats
# 0  ../exp_801_repeated/20230802030225_experiment_stats
# 0  ../exp_801_repeated/20230802030647_experiment_stats
# 0  ../exp_801_repeated/20230802072454_experiment_stats
# 0  ../exp_801_repeated/20230802074756_experiment_stats
# 0  ../exp_801_repeated/20230802092922_experiment_stats
# 0  ../exp_801_repeated/20230802110006_experiment_stats

# %%
show_trees('../exp_801_repeated/20230801213240')
# Out:
# ../exp_801_repeated/20230801213240_tree_brute_force_11_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_13_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_15_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_146_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_161_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_29_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_216_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_225_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_228_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_239_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_259_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_284_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_35_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_37_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_300_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_325_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_330_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_331_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_43_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_426_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_435_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_5_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_53_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_578_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_597_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_75_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_78_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_79_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_759_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_9_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_11_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_13_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_146_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_15_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_161_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_216_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_225_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_228_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_239_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_259_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_284_dot_file
# ../exp_801_repeated/20230801213240_tree_brute_force_29_dot_file

# %%
fs.sort()

# %%
fs[0]
# Out:
# '../exp_727_repeated_320/20230728061824_experiment_stats'

# %%
fs[-1]
# Out:
# '../exp_727_repeated_320/20230731131854_experiment_stats'

# %%
df.shape
# Out:
# (5000, 18)

# %%
# df1 = show_stats('../exp_repeat_320_only/')

# %%
# show_trees('../exp_repeat_320_only/')

# %%
df.head()
# Out:
#               strat  runtime  avg_tree_size_increase  num_complaints  \
# 0  information_gain    3.391                4.400000              32
# 0             naive    0.922               23.866667              32
# 0  information_gain    6.405                8.466667              96
# 0             naive    0.988               28.333333              96
# 0  information_gain    4.889                8.866667             160
#
#    confirmation_cnt  global_accuracy  fix_rate  confirm_preserve_rate  \
# 0               288            0.821     0.781                  0.993
# 0               288            0.821     0.969                  1.000
# 0               224            0.821     0.823                  1.000
# 0               224            0.821     0.958                  1.000
# 0               160            0.821     0.781                  0.988
#
#    new_global_accuracy  prev_signaled_cnt  new_signaled_cnt  num_functions  \
# 0                0.899               1411              1411             30
# 0                0.895               1411              1411             30
# 0                0.933               1411              1411             30
# 0                0.884               1411              1411             30
# 0                0.925               1411              1411             30
#
#    deletion_factor  post_fix_num_funcs  num_of_funcs_processed_by_algo  \
# 0              0.0                  30                              29
# 0              0.0                  30                              29
# 0              0.0                  30                              29
# 0              0.0                  30                              29
# 0              0.0                  30                              29
#
#    complaint_reached_max  confirm_reached_max  \
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
#
#                                                      fname
# 0  ../exp_727_repeated_320/20230728061824_experiment_stats
# 0  ../exp_727_repeated_320/20230728061839_experiment_stats
# 0  ../exp_727_repeated_320/20230728061851_experiment_stats
# 0  ../exp_727_repeated_320/20230728061908_experiment_stats
# 0  ../exp_727_repeated_320/20230728061921_experiment_stats

# %%
df=df.sort_values(by='fname')

# %%
df.shape
# Out:
# (5000, 18)

# %%
df['strat'] = df['strat'].str.replace('information_gain', 'decision tree')
df['user_input_size'] = df['num_complaints'] + df['confirmation_cnt']
df['complaint_ratio'] = df['num_complaints']/df['user_input_size']
df['complaint_ratio'] = df['complaint_ratio'].map(lambda x: f'{x * 100:.2f}%')
df['accuracy_improvement'] = df['new_global_accuracy']/df['global_accuracy']

# %%
df.shape
# Out:
# (5000, 21)

# %%
df_no_deletion=df[df['deletion_factor']==0]
df_deletion=df[df['complaint_ratio']=='50.00%']

# %%
df1=df_no_deletion.head(1000)
df2=df_no_deletion.head(2000)
df3=df_no_deletion.head(3000)
df4=df_no_deletion.head(4000)
df5=df_no_deletion.head(5000)

# %%
import seaborn as sns

# %%
def boxplot(df, x, y, group_name, group_value, xlabel, ylabel, title):
    sns.set(style="whitegrid")
    plt.figure(figsize=(8, 6))
    df=df[df[group_name]==group_value]
    strat_list = list(df['strat'].unique())
    strat_list.sort()
    sns.boxplot(data=df, x=x, y=y, hue='strat', hue_order=strat_list)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.savefig(f"graph_pdfs/box_{title}.pdf", format="pdf")
    plt.show()
#     plt.close(fig)

# %%
for input_size in list(df['user_input_size'].unique()):
#     line_plots(df=df_diff_user_input_runtime, 
#                x='complaint_ratio', 
#                y='runtime', 
#                xlabel='complaint_ratio',
#                ylabel='runtime(s)', 
#                title=f'user_input_size vs runtime (user_input_size={input_size})',
#                color_assignment_dict=line_color_assignment_dict, 
#                legend_pos='lower center',
#                group_name='user_input_size',
#                group_value=input_size,
#                gtype='general',
#                ylim=None)
    boxplot(df=df_no_deletion,x="complaint_ratio",y="runtime",
            group_name='user_input_size',
            group_value=input_size,
            xlabel="complaint_ratio", ylabel="runtime", 
            title=f'user_input_size vs runtime (user_input_size={input_size})')

# %%
for input_size in list(df['user_input_size'].unique()):
#     line_plots(df=df_diff_user_input_runtime, 
#                x='complaint_ratio', 
#                y='runtime', 
#                xlabel='complaint_ratio',
#                ylabel='runtime(s)', 
#                title=f'user_input_size vs runtime (user_input_size={input_size})',
#                color_assignment_dict=line_color_assignment_dict, 
#                legend_pos='lower center',
#                group_name='user_input_size',
#                group_value=input_size,
#                gtype='general',
#                ylim=None)
    boxplot(df=df1,x="complaint_ratio",y="fix_rate",
            group_name='user_input_size',
            group_value=input_size,
            xlabel="complaint_ratio", ylabel="fix_rate", 
            title=f'user_input_size vs fix_rate (user_input_size={input_size})')

# %%
for input_size in list(df['user_input_size'].unique()):
#     line_plots(df=df_diff_user_input_runtime, 
#                x='complaint_ratio', 
#                y='runtime', 
#                xlabel='complaint_ratio',
#                ylabel='runtime(s)', 
#                title=f'user_input_size vs runtime (user_input_size={input_size})',
#                color_assignment_dict=line_color_assignment_dict, 
#                legend_pos='lower center',
#                group_name='user_input_size',
#                group_value=input_size,
#                gtype='general',
#                ylim=None)
    boxplot(df=df2,x="complaint_ratio",y="fix_rate",
            group_name='user_input_size',
            group_value=input_size,
            xlabel="complaint_ratio", ylabel="fix_rate", 
            title=f'user_input_size vs fix_rate (user_input_size={input_size})')

# %%
for input_size in list(df['user_input_size'].unique()):
#     line_plots(df=df_diff_user_input_runtime, 
#                x='complaint_ratio', 
#                y='runtime', 
#                xlabel='complaint_ratio',
#                ylabel='runtime(s)', 
#                title=f'user_input_size vs runtime (user_input_size={input_size})',
#                color_assignment_dict=line_color_assignment_dict, 
#                legend_pos='lower center',
#                group_name='user_input_size',
#                group_value=input_size,
#                gtype='general',
#                ylim=None)
    boxplot(df=df3,x="complaint_ratio",y="fix_rate",
            group_name='user_input_size',
            group_value=input_size,
            xlabel="complaint_ratio", ylabel="fix_rate", 
            title=f'user_input_size vs fix_rate (user_input_size={input_size})')

# %%
for input_size in list(df['user_input_size'].unique()):
#     line_plots(df=df_diff_user_input_runtime, 
#                x='complaint_ratio', 
#                y='runtime', 
#                xlabel='complaint_ratio',
#                ylabel='runtime(s)', 
#                title=f'user_input_size vs runtime (user_input_size={input_size})',
#                color_assignment_dict=line_color_assignment_dict, 
#                legend_pos='lower center',
#                group_name='user_input_size',
#                group_value=input_size,
#                gtype='general',
#                ylim=None)
    boxplot(df=df4,x="complaint_ratio",y="fix_rate",
            group_name='user_input_size',
            group_value=input_size,
            xlabel="complaint_ratio", ylabel="fix_rate", 
            title=f'user_input_size vs fix_rate (user_input_size={input_size})')

# %%
for input_size in list(df['user_input_size'].unique()):
#     line_plots(df=df_diff_user_input_runtime, 
#                x='complaint_ratio', 
#                y='runtime', 
#                xlabel='complaint_ratio',
#                ylabel='runtime(s)', 
#                title=f'user_input_size vs runtime (user_input_size={input_size})',
#                color_assignment_dict=line_color_assignment_dict, 
#                legend_pos='lower center',
#                group_name='user_input_size',
#                group_value=input_size,
#                gtype='general',
#                ylim=None)
    boxplot(df=df5,x="complaint_ratio",y="fix_rate",
            group_name='user_input_size',
            group_value=input_size,
            xlabel="complaint_ratio", ylabel="fix_rate", 
            title=f'user_input_size vs fix_rate (user_input_size={input_size})')

# %%
df_no_deletion.sort_values(by=['strat','complaint_ratio'])[['complaint_ratio','fix_rate','strat',\
                                                            'complaint_reached_max','confirm_reached_max']]
# Out:
#   complaint_ratio  fix_rate          strat  complaint_reached_max  \
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     1.000  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.500  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     1.000  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.469  decision tree                  False
# 0          10.00%     1.000  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     1.000  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     1.000  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     1.000  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.469  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     1.000  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     1.000  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     1.000  decision tree                  False
# 0          10.00%     0.469  decision tree                  False
# 0          10.00%     0.469  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.344  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.469  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     1.000  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.500  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.438  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.469  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.438  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.469  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.469  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     1.000  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     1.000  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.500  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.938  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.844  decision tree                  False
# 0          10.00%     0.469  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.906  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.688  decision tree                  False
# 0          10.00%     0.500  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.656  decision tree                  False
# 0          10.00%     0.750  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.719  decision tree                  False
# 0          10.00%     0.812  decision tree                  False
# 0          10.00%     0.594  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.781  decision tree                  False
# 0          10.00%     0.625  decision tree                  False
# 0          10.00%     0.531  decision tree                  False
# 0          10.00%     0.562  decision tree                  False
# 0          10.00%     0.875  decision tree                  False
# 0          10.00%     0.969  decision tree                  False
# 0          30.00%     0.823  decision tree                  False
# 0          30.00%     0.656  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.875  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.969  decision tree                  False
# 0          30.00%     0.833  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.875  decision tree                  False
# 0          30.00%     0.667  decision tree                  False
# 0          30.00%     0.812  decision tree                  False
# 0          30.00%     0.833  decision tree                  False
# 0          30.00%     0.844  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.625  decision tree                  False
# 0          30.00%     0.854  decision tree                  False
# 0          30.00%     0.927  decision tree                  False
# 0          30.00%     0.844  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.938  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.802  decision tree                  False
# 0          30.00%     0.854  decision tree                  False
# 0          30.00%     0.688  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.958  decision tree                  False
# 0          30.00%     0.938  decision tree                  False
# 0          30.00%     0.562  decision tree                  False
# 0          30.00%     0.917  decision tree                  False
# 0          30.00%     0.917  decision tree                  False
# 0          30.00%     0.938  decision tree                  False
# 0          30.00%     0.958  decision tree                  False
# 0          30.00%     0.927  decision tree                  False
# 0          30.00%     0.865  decision tree                  False
# 0          30.00%     0.875  decision tree                  False
# 0          30.00%     0.938  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.865  decision tree                  False
# 0          30.00%     0.854  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.875  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.833  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.927  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.927  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.938  decision tree                  False
# 0          30.00%     0.573  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.729  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.823  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.865  decision tree                  False
# 0          30.00%     0.615  decision tree                  False
# 0          30.00%     0.708  decision tree                  False
# 0          30.00%     0.604  decision tree                  False
# 0          30.00%     0.958  decision tree                  False
# 0          30.00%     0.917  decision tree                  False
# 0          30.00%     0.990  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.969  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.958  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.677  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.969  decision tree                  False
# 0          30.00%     0.854  decision tree                  False
# 0          30.00%     0.854  decision tree                  False
# 0          30.00%     0.969  decision tree                  False
# 0          30.00%     0.844  decision tree                  False
# 0          30.00%     0.688  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.875  decision tree                  False
# 0          30.00%     0.812  decision tree                  False
# 0          30.00%     0.927  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.927  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.802  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.990  decision tree                  False
# 0          30.00%     0.958  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.865  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.927  decision tree                  False
# 0          30.00%     0.750  decision tree                  False
# 0          30.00%     0.604  decision tree                  False
# 0          30.00%     0.938  decision tree                  False
# 0          30.00%     0.969  decision tree                  False
# 0          30.00%     0.656  decision tree                  False
# 0          30.00%     0.844  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.865  decision tree                  False
# 0          30.00%     0.969  decision tree                  False
# 0          30.00%     0.844  decision tree                  False
# 0          30.00%     0.938  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.865  decision tree                  False
# 0          30.00%     0.844  decision tree                  False
# 0          30.00%     0.865  decision tree                  False
# 0          30.00%     0.958  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.625  decision tree                  False
# 0          30.00%     0.542  decision tree                  False
# 0          30.00%     0.760  decision tree                  False
# 0          30.00%     0.865  decision tree                  False
# 0          30.00%     0.958  decision tree                  False
# 0          30.00%     0.604  decision tree                  False
# 0          30.00%     0.917  decision tree                  False
# 0          30.00%     0.927  decision tree                  False
# 0          30.00%     0.865  decision tree                  False
# 0          30.00%     0.865  decision tree                  False
# 0          30.00%     0.927  decision tree                  False
# 0          30.00%     0.823  decision tree                  False
# 0          30.00%     0.812  decision tree                  False
# 0          30.00%     0.927  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.917  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.938  decision tree                  False
# 0          30.00%     0.917  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.875  decision tree                  False
# 0          30.00%     0.958  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.917  decision tree                  False
# 0          30.00%     0.667  decision tree                  False
# 0          30.00%     0.969  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.958  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.760  decision tree                  False
# 0          30.00%     0.594  decision tree                  False
# 0          30.00%     0.667  decision tree                  False
# 0          30.00%     0.854  decision tree                  False
# 0          30.00%     0.958  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.844  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.938  decision tree                  False
# 0          30.00%     0.635  decision tree                  False
# 0          30.00%     0.979  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.938  decision tree                  False
# 0          30.00%     0.635  decision tree                  False
# 0          30.00%     0.917  decision tree                  False
# 0          30.00%     0.927  decision tree                  False
# 0          30.00%     0.719  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.906  decision tree                  False
# 0          30.00%     0.896  decision tree                  False
# 0          30.00%     0.927  decision tree                  False
# 0          30.00%     0.698  decision tree                  False
# 0          30.00%     0.854  decision tree                  False
# 0          30.00%     0.875  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.958  decision tree                  False
# 0          30.00%     0.948  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.958  decision tree                  False
# 0          30.00%     0.938  decision tree                  False
# 0          30.00%     0.885  decision tree                  False
# 0          30.00%     0.521  decision tree                  False
# 0          30.00%     0.938  decision tree                  False
# 0          30.00%     0.938  decision tree                  False
# ...
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False
# 0                False

# %%
df_no_deletion.head()
# Out:
#            strat  runtime  avg_tree_size_increase  num_complaints  \
# 0  decision tree    3.391                4.400000              32
# 0          naive    0.922               23.866667              32
# 0  decision tree    6.405                8.466667              96
# 0          naive    0.988               28.333333              96
# 0  decision tree    4.889                8.866667             160
#
#    confirmation_cnt  global_accuracy  fix_rate  confirm_preserve_rate  \
# 0               288            0.821     0.781                  0.993
# 0               288            0.821     0.969                  1.000
# 0               224            0.821     0.823                  1.000
# 0               224            0.821     0.958                  1.000
# 0               160            0.821     0.781                  0.988
#
#    new_global_accuracy  prev_signaled_cnt  new_signaled_cnt  num_functions  \
# 0                0.899               1411              1411             30
# 0                0.895               1411              1411             30
# 0                0.933               1411              1411             30
# 0                0.884               1411              1411             30
# 0                0.925               1411              1411             30
#
#    deletion_factor  post_fix_num_funcs  num_of_funcs_processed_by_algo  \
# 0              0.0                  30                              29
# 0              0.0                  30                              29
# 0              0.0                  30                              29
# 0              0.0                  30                              29
# 0              0.0                  30                              29
#
#    complaint_reached_max  confirm_reached_max  \
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
# 0                  False                False
#
#                                                      fname  user_input_size  \
# 0  ../exp_727_repeated_320/20230728061824_experiment_stats              320
# 0  ../exp_727_repeated_320/20230728061839_experiment_stats              320
# 0  ../exp_727_repeated_320/20230728061851_experiment_stats              320
# 0  ../exp_727_repeated_320/20230728061908_experiment_stats              320
# 0  ../exp_727_repeated_320/20230728061921_experiment_stats              320
#
#   complaint_ratio  accuracy_improvement
# 0          10.00%              1.095006
# 0          10.00%              1.090134
# 0          30.00%              1.136419
# 0          30.00%              1.076736
# 0          50.00%              1.126675

# %%
for input_size in list(df['user_input_size'].unique()):
#     line_plots(df=df_diff_user_input_runtime, 
#                x='complaint_ratio', 
#                y='runtime', 
#                xlabel='complaint_ratio',
#                ylabel='runtime(s)', 
#                title=f'user_input_size vs runtime (user_input_size={input_size})',
#                color_assignment_dict=line_color_assignment_dict, 
#                legend_pos='lower center',
#                group_name='user_input_size',
#                group_value=input_size,
#                gtype='general',
#                ylim=None)
    boxplot(df=df_no_deletion,x="complaint_ratio",y="avg_tree_size_increase",
            group_name='user_input_size',
            group_value=input_size,
            xlabel="complaint_ratio", ylabel="avg_tree_size_increase", 
            title=f'user_input_size vs avg_tree_size_increase (user_input_size={input_size})')

# %%
for input_size in list(df['user_input_size'].unique()):
#     line_plots(df=df_diff_user_input_runtime, 
#                x='complaint_ratio', 
#                y='runtime', 
#                xlabel='complaint_ratio',
#                ylabel='runtime(s)', 
#                title=f'user_input_size vs runtime (user_input_size={input_size})',
#                color_assignment_dict=line_color_assignment_dict, 
#                legend_pos='lower center',
#                group_name='user_input_size',
#                group_value=input_size,
#                gtype='general',
#                ylim=None)
    boxplot(df=df_deletion,x="deletion_factor",y="avg_tree_size_increase",
            group_name='user_input_size',
            group_value=input_size,
            xlabel="deletion_factor", ylabel="avg_tree_size_increase", 
            title=f'deletion_factor vs avg_tree_size_increase (user_input_size={input_size})')

# %%
for input_size in list(df['user_input_size'].unique()):
#     line_plots(df=df_diff_user_input_runtime, 
#                x='complaint_ratio', 
#                y='runtime', 
#                xlabel='complaint_ratio',
#                ylabel='runtime(s)', 
#                title=f'user_input_size vs runtime (user_input_size={input_size})',
#                color_assignment_dict=line_color_assignment_dict, 
#                legend_pos='lower center',
#                group_name='user_input_size',
#                group_value=input_size,
#                gtype='general',
#                ylim=None)
    boxplot(df=df_deletion,x="deletion_factor",y="fix_rate",
            group_name='user_input_size',
            group_value=input_size,
            xlabel="deletion_factor", ylabel="fix_rate", 
            title=f'deletion_factor vs fix_rate (user_input_size={input_size})')
