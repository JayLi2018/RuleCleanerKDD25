# %%
import pandas as pd

# %%
df=pd.read_csv('/home/opc/chenjie/enron.csv')

# %%
rep_dict={'ham':0, 'spam':1}

# %%
df['label'].replace(rep_dict, inplace=True)

# %%
df[df['label']==1].head(20)
# Out:
#                                                     text  label
# 15045  Subject: hi\n how to save on your fashion medl...      1
# 15046  Subject: all graphics software available , che...      1
# 15047  Subject: upside pressure signals institutional...      1
# 15048  Subject: professionally - designed logos and i...      1
# 15049  Subject: we have been helping thousands of men...      1
# 15050  Subject: deal with your medication now\n hello...      1
# 15051  Subject: v and more\n hello , welcome to the m...      1
# 15052  Subject: make your rivals envy\n lt is really ...      1
# 15053  Subject: visual identity and logo now\n workin...      1
# 15054  Subject: save your money buy getting this thin...      1
# 15055  Subject: look what sandy is doing in her dorm ...      1
# 15056  Subject: if you own a cell phone . . . . . . p...      1
# 15057  Subject: urgent response\n dear sir / madam ,\...      1
# 15058  Subject: quick cash !\n sell your timeshare !\...      1
# ...

# %%
df.to_csv('/home/opc/chenjie/enron_int_labels.csv',index=False)
