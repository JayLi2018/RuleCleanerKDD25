# %%
# original rules
dc_file='/home/opc/chenjie/RBBM/rbbm_src/muse/data/mas/flights_dcfinder_rules.txt'
table_name='flights_new'
res=[]
rule_texts=[]
try:
    with open(dc_file, "r") as file:
        for line in file:
            rule_texts.append(line.strip())
            # rules_from_line = [(table_name, x) for x in convert_dc_to_muse_rule(line, 'adult', 't1')]
#             rules_from_line = [(table_name, x) for x in convert_dc_to_muse_rule(line, 'flights_new', 't1')]
#             res.extend(rules_from_line)
except FileNotFoundError:
    print("File not found.")
except IOError:
    print("Error reading the file.")

# %%
result_dict = {'t1&t2&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)']}, 't1&t2&IQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&IQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)']}, 't1&t2&IQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 9, 'fixed_treerule_text': ["t1&t2&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'4')&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&IQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)"]}, 't1&t2&EQ(t1.CRS_DEP_TIME,t2.CRS_DEP_TIME)': {'deleted': True, 'pre_fix_size': 3, 'after_fix_size': 43, 'fixed_treerule_text': ["t1&t2&EQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.day_of_week,'1')&EQ(t1.CRS_DEP_TIME,t2.CRS_DEP_TIME)", "t1&t2&EQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.CRS_DEP_TIME,t2.CRS_DEP_TIME)", "t1&t2&EQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t2.day_of_week,'5')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.day_of_week,'1')&EQ(t1.CRS_DEP_TIME,t2.CRS_DEP_TIME)", "t1&t2&EQ(t1.dep_time,t2.dep_time)&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.CRS_DEP_TIME,t2.CRS_DEP_TIME)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.CRS_DEP_TIME,t2.CRS_DEP_TIME)", "t1&t2&IQ(t2.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.CRS_DEP_TIME,t2.CRS_DEP_TIME)", "t1&t2&IQ(t1.fl_date,t2.fl_date)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'5')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.day_of_week,'1')&EQ(t1.CRS_DEP_TIME,t2.CRS_DEP_TIME)", "t1&t2&EQ(t1.day_of_week,'2')&EQ(t2.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.CRS_DEP_TIME,t2.CRS_DEP_TIME)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.CRS_DEP_TIME,t2.CRS_DEP_TIME)", "t1&t2&EQ(t2.day_of_week,'3')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.CRS_DEP_TIME,t2.CRS_DEP_TIME)", "t1&t2&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.CRS_DEP_TIME,t2.CRS_DEP_TIME)"]}, 't1&t2&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_airport_id,t2.origin_airport_id)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)']}, 't1&t2&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)']}, 't1&t2&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)']}, 't1&t2&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 81, 'fixed_treerule_text': ["t1&t2&EQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'3')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'5')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t1.day_of_week,'3')&EQ(t2.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,'6')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'5')&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t1.day_of_week,'1')&EQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'5')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t1.day_of_week,t2.day_of_week)&EQ(t2.day_of_week,'5')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)"]}, 't1&t2&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)': {'deleted': True, 'pre_fix_size': 3, 'after_fix_size': 101, 'fixed_treerule_text': ["t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t2.day_of_week,'6')&EQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'6')&EQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'6')&EQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.day_of_week,'4')&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'6')&EQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'6')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'7')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'2')&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'7')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'2')&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.day_of_week,'5')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.fl_date,t2.fl_date)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.fl_date,t2.fl_date)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t2.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.fl_date,t2.fl_date)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'5')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'7')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'2')&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t2.day_of_week,'3')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'5')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'7')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'2')&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t2.day_of_week,'6')&EQ(t1.day_of_week,'5')&IQ(t2.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.fl_date,t2.fl_date)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'6')&EQ(t1.day_of_week,'5')&IQ(t2.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.fl_date,t2.fl_date)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t1.day_of_week,'5')&IQ(t2.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.fl_date,t2.fl_date)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t1.day_of_week,'5')&IQ(t2.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.fl_date,t2.fl_date)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.day_of_week,'4')&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'6')&EQ(t1.day_of_week,'5')&IQ(t2.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.fl_date,t2.fl_date)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t1.day_of_week,'5')&IQ(t2.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.fl_date,t2.fl_date)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t1.day_of_week,'5')&IQ(t2.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.fl_date,t2.fl_date)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t2.day_of_week,'7')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t1.day_of_week,'5')&IQ(t2.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.fl_date,t2.fl_date)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t1.day_of_week,'5')&IQ(t2.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.fl_date,t2.fl_date)&IQ(t2.day_of_week,'3')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)"]}, 't1&t2&EQ(t1.ARR_TIME,t2.ARR_TIME)': {'deleted': True, 'pre_fix_size': 3, 'after_fix_size': 29, 'fixed_treerule_text': ["t1&t2&EQ(t2.day_of_week,'6')&EQ(t1.day_of_week,'1')&EQ(t1.ARR_TIME,t2.ARR_TIME)", "t1&t2&EQ(t1.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'1')&EQ(t1.ARR_TIME,t2.ARR_TIME)", "t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'1')&EQ(t1.ARR_TIME,t2.ARR_TIME)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'1')&EQ(t1.ARR_TIME,t2.ARR_TIME)", "t1&t2&IQ(t2.day_of_week,'4')&EQ(t1.day_of_week,'5')&IQ(t2.day_of_week,'3')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'1')&EQ(t1.ARR_TIME,t2.ARR_TIME)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'5')&IQ(t2.day_of_week,'3')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'1')&EQ(t1.ARR_TIME,t2.ARR_TIME)", "t1&t2&EQ(t1.day_of_week,'2')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'5')&IQ(t2.day_of_week,'3')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'1')&EQ(t1.ARR_TIME,t2.ARR_TIME)"]}, 't1&t2&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 21, 'fixed_treerule_text': ["t1&t2&EQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.day_of_week,'1')&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'1')&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'6')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'1')&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)"]}, 't1&t2&EQ(t1.DEST,t2.DEST)&EQ(t1.FL_DATE,t2.FL_DATE)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 17, 'fixed_treerule_text': ["t1&t2&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST,t2.DEST)", "t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST,t2.DEST)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST,t2.DEST)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST,t2.DEST)"]}, 't1&t2&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 31, 'fixed_treerule_text': ["t1&t2&EQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'3')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'3')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)", "t1&t2&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'3')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)", "t1&t2&IQ(t1.fl_date,t2.fl_date)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.fl_date,t2.fl_date)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)"]}, 't1&t2&EQ(t1.ORIGIN,t2.ORIGIN)&EQ(t1.FL_DATE,t2.FL_DATE)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.ORIGIN,t2.ORIGIN)']}, 't1&t2&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 153, 'fixed_treerule_text': ["t1&t2&EQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&IQ(t2.day_of_week,'2')&EQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,'5')&EQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&IQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'2')&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&EQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'2')&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,'2')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.day_of_week,'5')&EQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'5')&EQ(t2.day_of_week,'6')&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'4')&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&IQ(t1.day_of_week,'3')&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.day_of_week,'2')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.day_of_week,'5')&EQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'6')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'5')&EQ(t2.day_of_week,'6')&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'4')&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.day_of_week,'3')&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.day_of_week,'2')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.day_of_week,'5')&EQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,'6')&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&IQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'2')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,'3')&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'1')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'6')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'1')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'6')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'1')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'6')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'1')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'6')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,'5')&EQ(t1.day_of_week,'1')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'1')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'5')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.day_of_week,'1')&EQ(t2.day_of_week,'5')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,'5')&EQ(t2.day_of_week,'3')&EQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'5')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&IQ(t2.day_of_week,'3')&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'5')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.day_of_week,'1')&EQ(t2.day_of_week,'5')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t2.day_of_week,'3')&EQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'5')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)"]}, 't1&t2&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.FL_DATE,t2.FL_DATE)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 21, 'fixed_treerule_text': ["t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&IQ(t1.day_of_week,'3')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)"]}, 't1&t2&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST,t2.DEST)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 31, 'fixed_treerule_text': ["t1&t2&EQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'3')&EQ(t1.DEST,t2.DEST)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'3')&EQ(t1.DEST,t2.DEST)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.DEST,t2.DEST)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'3')&EQ(t1.DEST,t2.DEST)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.DEST,t2.DEST)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.DEST,t2.DEST)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t1.fl_date,t2.fl_date)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.DEST,t2.DEST)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.fl_date,t2.fl_date)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&EQ(t1.DEST,t2.DEST)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)"]}, 't1&t2&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)']}, 't1&t2&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.FL_DATE,t2.FL_DATE)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 37, 'fixed_treerule_text': ["t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&IQ(t1.day_of_week,'4')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&IQ(t1.day_of_week,'5')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'5')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)"]}, 't1&t2&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&EQ(t1.FL_DATE,t2.FL_DATE)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 23, 'fixed_treerule_text': ['t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)', "t1&t2&EQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'3')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.day_of_week,'3')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)"]}, 't1&t2&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)']}, 't1&t2&EQ(t1.ORIGIN,t2.ORIGIN)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&EQ(t1.ORIGIN,t2.ORIGIN)']}, 't1&t2&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)']}, 't1&t2&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&EQ(t1.day_of_week,t2.day_of_week)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)']}, 't1&t2&EQ(t1.DEP_TIME,t2.DEP_TIME)': {'deleted': True, 'pre_fix_size': 3, 'after_fix_size': 23, 'fixed_treerule_text': ["t1&t2&EQ(t1.day_of_week,'6')&IQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.DEP_TIME,t2.DEP_TIME)", "t1&t2&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&IQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.DEP_TIME,t2.DEP_TIME)", "t1&t2&IQ(t1.day_of_week,t2.day_of_week)&EQ(t1.day_of_week,'3')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.DEP_TIME,t2.DEP_TIME)", "t1&t2&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'3')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.DEP_TIME,t2.DEP_TIME)", "t1&t2&IQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'6')&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'3')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.DEP_TIME,t2.DEP_TIME)"]}, 't1&t2&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)']}, 't1&t2&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 21, 'fixed_treerule_text': ["t1&t2&EQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.day_of_week,'1')&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)", "t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'6')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)"]}, 't1&t2&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)']}, 't1&t2&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)': {'deleted': True, 'pre_fix_size': 3, 'after_fix_size': 53, 'fixed_treerule_text': ["t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&EQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t1.origin_airport_id,t2.origin_airport_id)&EQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&EQ(t1.distance,t2.distance)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&EQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'6')&IQ(t1.origin_airport_id,t2.origin_airport_id)&EQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'6')&IQ(t1.origin_airport_id,t2.origin_airport_id)&EQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&IQ(t1.day_of_week,t2.day_of_week)&EQ(t2.day_of_week,'6')&IQ(t1.distance,t2.distance)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'6')&IQ(t1.origin_airport_id,t2.origin_airport_id)&EQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&IQ(t2.day_of_week,'2')&EQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'6')&IQ(t1.origin_airport_id,t2.origin_airport_id)&EQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&EQ(t2.day_of_week,'4')&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'6')&IQ(t1.distance,t2.distance)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'6')&IQ(t1.distance,t2.distance)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'6')&IQ(t1.distance,t2.distance)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&EQ(t1.day_of_week,'4')&IQ(t2.day_of_week,'4')&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'6')&IQ(t1.distance,t2.distance)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&IQ(t2.day_of_week,'4')&EQ(t1.day_of_week,'3')&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'6')&IQ(t1.distance,t2.distance)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&EQ(t1.day_of_week,'6')&IQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'3')&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'6')&IQ(t1.distance,t2.distance)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)", "t1&t2&IQ(t1.day_of_week,'6')&EQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'3')&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'6')&IQ(t1.distance,t2.distance)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'5')&EQ(t1.CRS_ARR_TIME,t2.CRS_ARR_TIME)"]}, 't1&t2&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 81, 'fixed_treerule_text': ["t1&t2&EQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'3')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'5')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.day_of_week,'3')&EQ(t2.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.day_of_week,'6')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'5')&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.day_of_week,'1')&EQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'5')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.day_of_week,t2.day_of_week)&EQ(t2.day_of_week,'5')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)"]}, 't1&t2&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&EQ(t1.DEST,t2.DEST)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&EQ(t1.day_of_week,t2.day_of_week)&EQ(t1.DEST,t2.DEST)&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)']}, 't1&t2&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 53, 'fixed_treerule_text': ['t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)', "t1&t2&EQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.fl_date,t2.fl_date)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.day_of_week,'3')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&IQ(t1.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.fl_date,t2.fl_date)&EQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.day_of_week,'2')&IQ(t1.distance,t2.distance)&IQ(t1.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.fl_date,t2.fl_date)&IQ(t1.day_of_week,'2')&IQ(t1.distance,t2.distance)&IQ(t1.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)"]}, 't1&t2&EQ(t1.ORIGIN,t2.ORIGIN)&IQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&IQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&EQ(t1.ORIGIN,t2.ORIGIN)']}, 't1&t2&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&IQ(t1.ORIGIN,t2.ORIGIN)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.ORIGIN,t2.ORIGIN)&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)']}, 't1&t2&EQ(t1.ORIGIN,t2.ORIGIN)&EQ(t1.DEST,t2.DEST)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST,t2.DEST)&EQ(t1.ORIGIN,t2.ORIGIN)']}, 't1&t2&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DEST,t2.DEST)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 21, 'fixed_treerule_text': ["t1&t2&EQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.day_of_week,'1')&EQ(t1.DEST,t2.DEST)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.DEST,t2.DEST)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'6')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.DEST,t2.DEST)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)"]}, 't1&t2&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)']}, 't1&t2&IQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&IQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)']}, 't1&t2&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.FL_DATE,t2.FL_DATE)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 37, 'fixed_treerule_text': ["t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t1.day_of_week,'4')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t1.day_of_week,'5')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'5')&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)"]}, 't1&t2&IQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.ORIGIN,t2.ORIGIN)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.ORIGIN,t2.ORIGIN)&IQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)']}, 't1&t2&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)']}, 't1&t2&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)']}, 't1&t2&EQ(t1.ORIGIN,t2.ORIGIN)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN,t2.ORIGIN)']}, 't1&t2&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)']}, 't1&t2&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 81, 'fixed_treerule_text': ["t1&t2&EQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'3')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'5')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.day_of_week,'3')&EQ(t2.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.day_of_week,'6')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'5')&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.day_of_week,'1')&EQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'5')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.day_of_week,t2.day_of_week)&EQ(t2.day_of_week,'5')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)"]}, 't1&t2&EQ(t1.ORIGIN,t2.ORIGIN)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.ORIGIN,t2.ORIGIN)']}, 't1&t2&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 21, 'fixed_treerule_text': ["t1&t2&EQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.day_of_week,'1')&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'1')&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'6')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'1')&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)"]}, 't1&t2&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.DEST,t2.DEST)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.DEST,t2.DEST)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)']}, 't1&t2&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&EQ(t1.FL_DATE,t2.FL_DATE)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)']}, 't1&t2&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)': {'deleted': True, 'pre_fix_size': 9, 'after_fix_size': 255, 'fixed_treerule_text': ["t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'5')&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t2.day_of_week,'4')&EQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t2.day_of_week,'4')&EQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'3')&EQ(t2.day_of_week,'2')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'6')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.arr_time,t2.arr_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&EQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t2.day_of_week,'2')&EQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.distance,t2.distance)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'2')&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'4')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.crs_arr_time,t2.crs_arr_time)&EQ(t2.day_of_week,'4')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'2')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'2')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'6')&IQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'2')&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'6')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.arr_time,t2.arr_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t2.day_of_week,'6')&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t2.day_of_week,'6')&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'4')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'7')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'2')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.arr_time,t2.arr_time)&EQ(t2.day_of_week,'5')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.distance,t2.distance)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'2')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t2.day_of_week,'3')&EQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'6')&IQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'2')&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.dep_time,t2.dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'5')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.distance,t2.distance)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'6')&EQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.distance,t2.distance)&IQ(t1.arr_time,t2.arr_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'2')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'7')&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'2')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'6')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'5')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.distance,t2.distance)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'1')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'6')&EQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'5')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.distance,t2.distance)&IQ(t1.arr_time,t2.arr_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'2')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'6')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'5')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.distance,t2.distance)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.arr_time,t2.arr_time)&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'1')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'6')&EQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.dep_time,t2.dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.distance,t2.distance)&IQ(t1.arr_time,t2.arr_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'2')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'6')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'5')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.distance,t2.distance)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'1')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'3')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'1')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t2.day_of_week,'2')&EQ(t2.day_of_week,'4')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'6')&EQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t2.day_of_week,'2')&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'3')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'1')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.distance,t2.distance)&IQ(t1.arr_time,t2.arr_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'4')&EQ(t2.day_of_week,'2')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'3')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'1')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'6')&IQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.distance,t2.distance)&IQ(t1.arr_time,t2.arr_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)"]}, 't1&t2&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)&EQ(t1.FL_DATE,t2.FL_DATE)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)']}, 't1&t2&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)']}, 't1&t2&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.FL_DATE,t2.FL_DATE)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 23, 'fixed_treerule_text': ['t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)', "t1&t2&EQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'3')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,'3')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)"]}, 't1&t2&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)']}, 't1&t2&IQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)']}, 't1&t2&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 21, 'fixed_treerule_text': ["t1&t2&EQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.day_of_week,'1')&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'6')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)"]}, 't1&t2&EQ(t1.ORIGIN,t2.ORIGIN)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN,t2.ORIGIN)']}, 't1&t2&EQ(t1.DISTANCE,t2.DISTANCE)': {'deleted': True, 'pre_fix_size': 3, 'after_fix_size': 35, 'fixed_treerule_text': ["t1&t2&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&EQ(t1.DISTANCE,t2.DISTANCE)", "t1&t2&EQ(t2.day_of_week,'3')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&EQ(t1.DISTANCE,t2.DISTANCE)", "t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&EQ(t1.DISTANCE,t2.DISTANCE)", "t1&t2&EQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t2.day_of_week,'3')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&EQ(t1.DISTANCE,t2.DISTANCE)", "t1&t2&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t2.day_of_week,'3')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&EQ(t1.DISTANCE,t2.DISTANCE)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t2.day_of_week,'3')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&EQ(t1.DISTANCE,t2.DISTANCE)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'3')&IQ(t1.origin_airport_id,t2.origin_airport_id)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&EQ(t1.DISTANCE,t2.DISTANCE)", "t1&t2&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'3')&IQ(t1.origin_airport_id,t2.origin_airport_id)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&EQ(t1.DISTANCE,t2.DISTANCE)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t2.day_of_week,'3')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&EQ(t1.DISTANCE,t2.DISTANCE)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'3')&IQ(t1.origin_airport_id,t2.origin_airport_id)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&EQ(t1.DISTANCE,t2.DISTANCE)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'3')&IQ(t1.origin_airport_id,t2.origin_airport_id)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'3')&EQ(t1.DISTANCE,t2.DISTANCE)"]}, 't1&t2&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)']}, 't1&t2&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 81, 'fixed_treerule_text': ["t1&t2&EQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'3')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.dest_city_name,t2.dest_city_name)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'5')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t1.day_of_week,'3')&EQ(t2.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'6')&IQ(t1.day_of_week,'1')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,'6')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'5')&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t1.day_of_week,'1')&EQ(t2.day_of_week,'4')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&EQ(t2.day_of_week,'5')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)", "t1&t2&IQ(t1.day_of_week,t2.day_of_week)&EQ(t2.day_of_week,'5')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t2.day_of_week,'4')&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'5')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)"]}, 't1&t2&EQ(t1.ORIGIN,t2.ORIGIN)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN,t2.ORIGIN)']}, 't1&t2&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)']}, 't1&t2&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 53, 'fixed_treerule_text': ['t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)', "t1&t2&EQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t1.fl_date,t2.fl_date)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.dest_state_abr,t2.dest_state_abr)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t1.day_of_week,'3')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&IQ(t1.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.fl_date,t2.fl_date)&EQ(t1.day_of_week,'3')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&EQ(t1.day_of_week,'2')&IQ(t1.distance,t2.distance)&IQ(t1.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)", "t1&t2&IQ(t1.fl_date,t2.fl_date)&IQ(t1.day_of_week,'2')&IQ(t1.distance,t2.distance)&IQ(t1.day_of_week,'1')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'6')&IQ(t1.dest_state_abr,t2.dest_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'4')&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)"]}, 't1&t2&IQ(t1.DEST,t2.DEST)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&IQ(t1.DEST,t2.DEST)']}, 't1&t2&IQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&EQ(t1.DEST,t2.DEST)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.DEST,t2.DEST)&IQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)']}, 't1&t2&EQ(t1.OP_CARRIER_FL_NUM,t2.OP_CARRIER_FL_NUM)': {'deleted': True, 'pre_fix_size': 3, 'after_fix_size': 9, 'fixed_treerule_text': ["t1&t2&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'4')&EQ(t1.OP_CARRIER_FL_NUM,t2.OP_CARRIER_FL_NUM)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'4')&EQ(t1.OP_CARRIER_FL_NUM,t2.OP_CARRIER_FL_NUM)"]}, 't1&t2&EQ(t1.DEST,t2.DEST)&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&IQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.DEST,t2.DEST)']}, 't1&t2&IQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)&IQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)']}, 't1&t2&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&IQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)']}, 't1&t2&EQ(t1.DEST,t2.DEST)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 7, 'fixed_treerule_text': ['t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)&EQ(t1.DEST,t2.DEST)']}, 't1&t2&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 39, 'fixed_treerule_text': ["t1&t2&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'5')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t1.day_of_week,'5')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&EQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'5')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&IQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t1.day_of_week,'5')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t1.day_of_week,'5')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&EQ(t1.day_of_week,'4')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'5')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'4')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'5')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'4')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'5')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'4')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'5')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'3')&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'4')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'5')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)", "t1&t2&IQ(t1.fl_date,t2.fl_date)&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.day_of_week,'3')&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'4')&EQ(t1.dest_airport_id,t2.dest_airport_id)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'5')&EQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)"]}, 't1&t2&IQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.DEST,t2.DEST)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.DEST,t2.DEST)&IQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)']}, 't1&t2&IQ(t1.DEST,t2.DEST)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 9, 'fixed_treerule_text': ["t1&t2&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'4')&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&IQ(t1.DEST,t2.DEST)"]}, 't1&t2&IQ(t1.ORIGIN,t2.ORIGIN)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)&IQ(t1.ORIGIN,t2.ORIGIN)']}, 't1&t2&EQ(t1.ORIGIN,t2.ORIGIN)&IQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&IQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)&EQ(t1.ORIGIN,t2.ORIGIN)']}, 't1&t2&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)': {'deleted': True, 'pre_fix_size': 9, 'after_fix_size': 255, 'fixed_treerule_text': ["t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'5')&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'4')&EQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'4')&EQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'3')&EQ(t2.day_of_week,'2')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'6')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.arr_time,t2.arr_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&EQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'2')&EQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.distance,t2.distance)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'2')&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'4')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.crs_arr_time,t2.crs_arr_time)&EQ(t2.day_of_week,'4')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'2')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'2')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'6')&IQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'2')&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'6')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.arr_time,t2.arr_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'6')&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'6')&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'4')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t2.day_of_week,'5')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'7')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'2')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.arr_time,t2.arr_time)&EQ(t2.day_of_week,'5')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.distance,t2.distance)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'2')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'3')&EQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'6')&IQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'2')&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.dep_time,t2.dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'5')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.distance,t2.distance)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'6')&EQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.distance,t2.distance)&IQ(t1.arr_time,t2.arr_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'2')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'7')&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'2')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'6')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'5')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.distance,t2.distance)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'1')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'6')&EQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'5')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.distance,t2.distance)&IQ(t1.arr_time,t2.arr_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'2')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'6')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'5')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.distance,t2.distance)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.arr_time,t2.arr_time)&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'1')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'6')&EQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.dep_time,t2.dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.distance,t2.distance)&IQ(t1.arr_time,t2.arr_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'2')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t2.day_of_week,'3')&IQ(t1.distance,t2.distance)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'6')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'5')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.distance,t2.distance)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'1')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'3')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'1')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'2')&EQ(t2.day_of_week,'4')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'6')&EQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'2')&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'3')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'1')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.distance,t2.distance)&IQ(t1.arr_time,t2.arr_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'4')&EQ(t2.day_of_week,'2')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'7')&IQ(t1.distance,t2.distance)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'3')&IQ(t1.arr_time,t2.arr_time)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'1')&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.distance,t2.distance)&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.dep_time,t2.dep_time)&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t2.day_of_week,'6')&IQ(t2.day_of_week,'3')&IQ(t1.dep_time,t2.dep_time)&EQ(t2.day_of_week,'5')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.distance,t2.distance)&IQ(t1.arr_time,t2.arr_time)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&IQ(t1.crs_arr_time,t2.crs_arr_time)&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.crs_dep_time,t2.crs_dep_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t1.day_of_week,'6')&IQ(t1.day_of_week,'1')&IQ(t1.day_of_week,'3')&IQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&IQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)"]}, 't1&t2&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 153, 'fixed_treerule_text': ["t1&t2&EQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'2')&EQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.day_of_week,'5')&EQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'2')&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&EQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'2')&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.day_of_week,'2')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.day_of_week,'5')&EQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'6')&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'5')&EQ(t2.day_of_week,'6')&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'4')&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t1.day_of_week,'3')&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.day_of_week,'2')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.day_of_week,'5')&EQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'6')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'3')&IQ(t2.day_of_week,'5')&EQ(t2.day_of_week,'6')&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'4')&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.day_of_week,'3')&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.day_of_week,'2')&IQ(t1.crs_dep_time,t2.crs_dep_time)&IQ(t1.day_of_week,'5')&EQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.day_of_week,'6')&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,t2.day_of_week)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'2')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.day_of_week,'3')&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'1')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'6')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'1')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'6')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'1')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'6')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t2.day_of_week,'4')&IQ(t2.day_of_week,'5')&EQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'2')&IQ(t1.day_of_week,t2.day_of_week)&IQ(t2.day_of_week,'1')&IQ(t1.fl_date,t2.fl_date)&IQ(t1.origin_state_abr,t2.origin_state_abr)&IQ(t2.day_of_week,'6')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.day_of_week,'4')&IQ(t1.day_of_week,'5')&IQ(t1.day_of_week,'6')&EQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.day_of_week,'5')&EQ(t1.day_of_week,'1')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'1')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'5')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t1.day_of_week,t2.day_of_week)&IQ(t1.day_of_week,'1')&EQ(t2.day_of_week,'5')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.day_of_week,'5')&EQ(t2.day_of_week,'3')&EQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'5')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'3')&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'5')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.day_of_week,'1')&EQ(t2.day_of_week,'5')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)", "t1&t2&EQ(t1.day_of_week,t2.day_of_week)&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t2.day_of_week,'3')&EQ(t1.day_of_week,'1')&IQ(t2.day_of_week,'5')&IQ(t1.actual_elapsed_time,t2.actual_elapsed_time)&EQ(t2.day_of_week,'4')&IQ(t1.day_of_week,'2')&IQ(t2.day_of_week,'7')&IQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.origin_airport_id,t2.origin_airport_id)&IQ(t1.fl_date,t2.fl_date)&EQ(t2.day_of_week,'2')&IQ(t1.day_of_week,'3')&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t2.day_of_week,'1')&IQ(t1.day_of_week,'4')&IQ(t1.dest_airport_id,t2.dest_airport_id)&EQ(t1.OP_UNIQUE_CARRIER,t2.OP_UNIQUE_CARRIER)&EQ(t1.DEST_STATE_NM,t2.DEST_STATE_NM)"]}, 't1&t2&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&EQ(t1.DEST,t2.DEST)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 21, 'fixed_treerule_text': ["t1&t2&EQ(t1.op_carrier_fl_num,t2.op_carrier_fl_num)&IQ(t1.day_of_week,'1')&EQ(t1.DEST,t2.DEST)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t1.origin_city_name,t2.origin_city_name)&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.DEST,t2.DEST)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)", "t1&t2&IQ(t2.day_of_week,'5')&IQ(t2.day_of_week,'1')&IQ(t2.day_of_week,'6')&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.DEST,t2.DEST)&EQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)"]}, 't1&t2&IQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)&IQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)']}, 't1&t2&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)&EQ(t1.FL_DATE,t2.FL_DATE)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&EQ(t1.FL_DATE,t2.FL_DATE)&IQ(t1.DAY_OF_WEEK,t2.DAY_OF_WEEK)']}, 't1&t2&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&EQ(t1.FL_DATE,t2.FL_DATE)': {'deleted': True, 'pre_fix_size': 5, 'after_fix_size': 17, 'fixed_treerule_text': ["t1&t2&IQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)", "t1&t2&IQ(t1.origin_state_abr,t2.origin_state_abr)&EQ(t1.op_unique_carrier,t2.op_unique_carrier)&EQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)", "t1&t2&EQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)", "t1&t2&IQ(t1.op_unique_carrier,t2.op_unique_carrier)&IQ(t1.origin_city_name,t2.origin_city_name)&EQ(t1.day_of_week,'3')&IQ(t1.day_of_week,'1')&EQ(t1.FL_DATE,t2.FL_DATE)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)"]}, 't1&t2&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)']}, 't1&t2&EQ(t1.ORIGIN,t2.ORIGIN)&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)': {'deleted': False, 'pre_fix_size': 5, 'after_fix_size': 5, 'fixed_treerule_text': ['t1&t2&IQ(t1.ORIGIN_STATE_NM,t2.ORIGIN_STATE_NM)&EQ(t1.ORIGIN,t2.ORIGIN)']}}

# %%
rule_texts
# Out:
# ['t1&t2&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)',
#  't1&t2&IQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)',
#  't1&t2&IQ(t1.DEST_AIRPORT_ID,t2.DEST_AIRPORT_ID)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)',
#  't1&t2&EQ(t1.CRS_DEP_TIME,t2.CRS_DEP_TIME)',
#  't1&t2&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)',
#  't1&t2&EQ(t1.ORIGIN_CITY_NAME,t2.ORIGIN_CITY_NAME)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)',
#  't1&t2&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.ORIGIN_AIRPORT_ID,t2.ORIGIN_AIRPORT_ID)',
#  't1&t2&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)&EQ(t1.DEST_STATE_ABR,t2.DEST_STATE_ABR)',
#  't1&t2&EQ(t1.ACTUAL_ELAPSED_TIME,t2.ACTUAL_ELAPSED_TIME)',
#  't1&t2&EQ(t1.ARR_TIME,t2.ARR_TIME)',
#  't1&t2&EQ(t1.DEST_CITY_NAME,t2.DEST_CITY_NAME)&EQ(t1.ORIGIN_STATE_ABR,t2.ORIGIN_STATE_ABR)',
#  't1&t2&EQ(t1.DEST,t2.DEST)&EQ(t1.FL_DATE,t2.FL_DATE)',
# ...

# %%
non_predelete_rules = list(result_dict)

# %%
len(rule_texts)
# Out:
# 83

# %%
len(non_predelete_rules)
# Out:
# 83

# %%
[x for x in rule_texts if x not in non_predelete_rules]
# Out:
# []
