# %%
# from lfs_tree import *
import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)
import pydot
import networkx as nx
from string import Template
import pandas as pd
import glob
import pydot
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

from IPython.display import Image, display
import matplotlib.pyplot as plt

# %%
def view_pydot(pdot):
    plt = Image(pdot.create_png())
    display(plt)
#     plt.savefig(f'dc_tree.pdf', format='pdf')
def show_trees(directory):
    treefiles = glob.glob(f'{directory}*tree_*')
    num_trees_per_strat = len(treefiles)
    for f in glob.glob(f'{directory}*tree_*'):
        file = open(f)
        dot_string = file.read()
        print(f)
        print(dot_string)
        graph = pydot.graph_from_dot_data(dot_string)[0]
        view_pydot(graph)
        print('\n')

# %%
df = pd.read_csv('../../muse/data/mas/tax.csv')
df.columns = ["FName","LName","Gender","AreaCode","Phone","City","State","Zip","MaritalStatus","HasChild","Salary","Rate","SingleExemp","MarriedExemp","ChildExemp","_tid_","is_dirty"]

# %%
show_trees('../../dc_src/test_dc_dot_2/')
# Out:
# ../../dc_src/test_dc_dot_2/20230913163618_tree_t1&t2&EQ(t1.AreaCode,t2.AreaCode)&EQ(t1.Phone,t2.Phone)_dot_file
# digraph "rule" {
# // presize: 5, after_size: 5,                 deleted: False
# 0 [label="dc-attr-pred-EQ(t1.AreaCode,t2.AreaCode)"]
# 0->1
# 0->2
# 1 [label="0 1: (
# 0: ((t1:1605, t2:184) (t1:803, t2:786) (t1:861, t2:143) "]
# 2 [label="dc-attr-pred-EQ(t1.Phone,t2.Phone)"]
# 2->3
# 2->4
# 3 [label="0 1: (
# 0: ((t1:385, t2:1574) (t1:1129, t2:1796) "]
# 4 [label="1 1: (
# 0: ("]
# //1605,184,803,786,861,143,385,1574,1129,1796
# } }
# ../../dc_src/test_dc_dot_2/20230913163618_tree_t1&t2&IQ(t1.City,t2.City)&EQ(t1.Zip,t2.Zip)_dot_file
# digraph "rule" {
# // presize: 5, after_size: 5,                 deleted: False
# 0 [label="dc-attr-pred-IQ(t1.City,t2.City)"]
# 0->1
# 0->2
# 1 [label="0 1: (
# 0: ("]
# 2 [label="dc-attr-pred-EQ(t1.Zip,t2.Zip)"]
# 2->3
# 2->4
# 3 [label="0 1: (
# 0: ((t1:385, t2:1574) (t1:1605, t2:184) (t1:1129, t2:1796) (t1:803, t2:786)
# ...
