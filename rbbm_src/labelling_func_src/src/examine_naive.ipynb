# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# %%
df=pd.read_csv('see some more song open google and type shakira guruofmovie﻿_results.csv')

# %%
df = df[['explainer', 'num_s_with_A', 'num_result_A', 'num_s_not_with_A', 'num_resul_notA', 'score']]

# %% [markdown]
# # $1_{M_F(s_0) = M(s_0)}$($E_{z \in S| A}$[$1_{M_F(z) = M(s_0)}$] - $E_{z \in S|\neg A}$[$1_{M(z) = M(s_0)}$])
#
# <ul>
# <li>Input: candidate explanation $E = F \cup A$</li>
# <li>Model M, corpus S, and sentence of interest $s_0$</li>
# </ul>

# %% [markdown]
# functions:
# <ul>
# <li>keyword_shakira(HAM)</li>
# <li>keyword_my(SPAM)</li>
# <li>keyword_subscribe(SPAM)</li>
# <li>keyword_link(SPAM)</li>
# <li>keyword_song(HAM)</li>
# <li>short_comment(HAM): HAM if len(x.text.split()) < 5 ELSE ABSTAIN</li>
# </ul>

# %%
df.head(100)
# Out:
#                                                                                                                                                                    explainer  \
# 0   {'words': ['song'], 'funcs': [func: keyword_song]}
# 1   {'words': ['song'], 'funcs': [func: keyword_shakira, func: keyword_song]}
# 2   {'words': ['song'], 'funcs': [func: keyword_song, func: short_comment]}
# 3   {'words': ['song'], 'funcs': [func: keyword_shakira, func: keyword_song, func: short_comment]}
# 4   {'words': ['song'], 'funcs': [func: keyword_shakira, func: keyword_http, func: keyword_song]}
# 5   {'words': ['song'], 'funcs': [func: keyword_shakira, func: keyword_http, func: keyword_song, func: short_comment]}
# 6   {'words': ['shakira'], 'funcs': [func: keyword_shakira]}
# 7   {'words': ['shakira'], 'funcs': [func: keyword_shakira, func: keyword_subscribe]}
# 8   {'words': ['shakira'], 'funcs': [func: keyword_shakira, func: keyword_song]}
# ...

# %%
df.tail(300)
# Out:
#                                                                                                                                       explainer  \
# 64149  {'words': ['type', 'song'], 'funcs': [func: keyword_subscribe, func: short_comment]}
# 64150  {'words': ['type', 'song'], 'funcs': [func: keyword_http, func: short_comment]}
# 64151  {'words': ['type', 'song'], 'funcs': [func: keyword_my, func: keyword_subscribe, func: keyword_http]}
# 64152  {'words': ['type', 'song'], 'funcs': [func: keyword_my, func: keyword_subscribe, func: short_comment]}
# 64153  {'words': ['type', 'song'], 'funcs': [func: keyword_my, func: keyword_http, func: short_comment]}
# 64154  {'words': ['type', 'song'], 'funcs': [func: keyword_subscribe, func: keyword_http, func: short_comment]}
# 64155  {'words': ['type', 'song'], 'funcs': [func: keyword_my, func: keyword_subscribe, func: keyword_http, func: short_comment]}
# 64156  {'words': ['open', 'and'], 'funcs': [func: keyword_my]}
# ...

# %%
df.iloc[10000:10500, :]
# Out:
#                                                                                                                                                                                        explainer  \
# 10000  {'words': ['more', 'shakira', 'google', 'and'], 'funcs': [func: keyword_song, func: short_comment]}
# 10001  {'words': ['more', 'shakira', 'google', 'and'], 'funcs': [func: keyword_shakira, func: keyword_my, func: keyword_subscribe]}
# 10002  {'words': ['more', 'shakira', 'google', 'and'], 'funcs': [func: keyword_shakira, func: keyword_my, func: keyword_http]}
# 10003  {'words': ['more', 'shakira', 'google', 'and'], 'funcs': [func: keyword_shakira, func: keyword_my, func: keyword_song]}
# 10004  {'words': ['more', 'shakira', 'google', 'and'], 'funcs': [func: keyword_shakira, func: keyword_my, func: short_comment]}
# 10005  {'words': ['more', 'shakira', 'google', 'and'], 'funcs': [func: keyword_shakira, func: keyword_subscribe, func: keyword_http]}
# ...
